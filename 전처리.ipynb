# %% [markdown]
# 결측치

# %%
import pandas as pd
data = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')
data

# 결측치 확인
print(data.isnull().sum())
data.isnull()
# Out:
# Axis [nm]    0
# ROI 1 []     0
# ROI 2 []     0
# ROI 3 []     0
# ROI 4 []     0
# ROI 5 []     0
# ROI 6 []     0
# ROI 7 []     0
# ROI 8 []     0
# ROI 9 []     0
# ROI 10 []    0
# ROI 11 []    0
# ROI 12 []    0
# ROI 13 []    0
# dtype: int64
#      Axis [nm]  ROI 1 []  ROI 2 []  ROI 3 []  ROI 4 []  ROI 5 []  ROI 6 []  \
# 0        False     False     False     False     False     False     False
# 1        False     False     False     False     False     False     False
# 2        False     False     False     False     False     False     False
# 3        False     False     False     False     False     False     False
# 4        False     False     False     False     False     False     False
# ..         ...       ...       ...       ...       ...       ...       ...
# 541      False     False     False     False     False     False     False
# 542      False     False     False     False     False     False     False
# ...

# %%
# 결측치 확인
print(data.isnull().sum())
data.isnull()

# 결측치 없음

# 결측지 정보
# data.isnull().sum()
# Out:
# Axis [nm]    0
# ROI 1 []     1
# ROI 2 []     0
# ROI 3 []     0
# ROI 4 []     0
# ROI 5 []     0
# ROI 6 []     0
# ROI 7 []     0
# ROI 8 []     0
# ROI 9 []     0
# ROI 10 []    0
# ROI 11 []    0
# ROI 12 []    0
# ROI 13 []    0
# dtype: int64
#      Axis [nm]  ROI 1 []  ROI 2 []  ROI 3 []  ROI 4 []  ROI 5 []  ROI 6 []  \
# 0        False     False     False     False     False     False     False
# 1        False      True     False     False     False     False     False
# 2        False     False     False     False     False     False     False
# 3        False     False     False     False     False     False     False
# 4        False     False     False     False     False     False     False
# ..         ...       ...       ...       ...       ...       ...       ...
# 541      False     False     False     False     False     False     False
# 542      False     False     False     False     False     False     False
# ...

# %% [markdown]
# 데이터 타입 확인

# %%
import pandas as pd

data = pd.read_csv('/UR2 BXPC3 raman raw data__24h.csv')
data.dtypes
# Out:
# Axis [nm]    float64
# ROI 1 []     float64
# ROI 2 []     float64
# ROI 3 []     float64
# ROI 4 []     float64
# ROI 5 []     float64
# ROI 6 []     float64
# ROI 7 []     float64
# ROI 8 []     float64
# ROI 9 []     float64
# ROI 10 []    float64
# ROI 11 []    float64
# ROI 12 []    float64
# ROI 13 []    float64
# dtype: object

# %% [markdown]
# ----------------------------------------------------
# 이상치 제거

# %%
import numpy as np
import pandas as pd

import pandas as pd
data = pd.read_csv('/UR2 BXPC3 raman raw data__24h.csv')
data


# 이상치 제거 함수
def remove_outliers(data, columns, threshold=3):
    for column in columns:
        # 평균과 표준 편차 계산
        mean = np.mean(data[column].values)
        std = np.std(data[column].values)

        # 임계값 설정
        lower_threshold = mean - threshold * std
        upper_threshold = mean + threshold * std

        # 이상치 제거
        data = data[(data[column] >= lower_threshold) & (data[column] <= upper_threshold)]

    return data



# 이상치 제거 적용
outlier_columns = ['ROI 1', 'ROI 2', 'ROI 3', 'ROI 4', 'ROI 5', 'ROI 6', 'ROI 7', 'ROI 8', 'ROI 9', 'ROI 10', 'ROI 11', 'ROI 12', 'ROI 13']
data_filtered = remove_outliers(data, outlier_columns)

# 이상치 제거된 데이터 확인
print(data_filtered.head())

# %% [markdown]
# ------------------------------------------------------------
# 소수점

# %%
import pandas as pd
import numpy as np

# CSV 파일 읽기
data = pd.read_csv('/UR2 BXPC3 raman raw data__24h.csv')

# 이상치 제거 함수
def remove_outliers(data, columns, threshold=3):
    for column in columns:
        # 평균과 표준 편차 계산
        mean = np.mean(data[column].values)
        std = np.std(data[column].values)

        # 임계값 설정
        lower_threshold = mean - threshold * std
        upper_threshold = mean + threshold * std

        # 이상치 제거
        data = data[(data[column] >= lower_threshold) & (data[column] <= upper_threshold)]

    return data

# 이상치 제거 적용
outlier_columns = ['ROI 1', 'ROI 2', 'ROI 3', 'ROI 4', 'ROI 5', 'ROI 6', 'ROI 7', 'ROI 8', 'ROI 9', 'ROI 10', 'ROI 11', 'ROI 12', 'ROI 13']
data_filtered = remove_outliers(data, outlier_columns)

# 소수점 전처리
data_filtered = data_filtered.round(decimals=2)

# 이상치 제거된 데이터 확인
print(data_filtered.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-8201c0f380b3> in <cell line: 25>()
#      23 # 이상치 제거 적용
#      24 outlier_columns = ['ROI 1', 'ROI 2', 'ROI 3', 'ROI 4', 'ROI 5', 'ROI 6', 'ROI 7', 'ROI 8', 'ROI 9', 'ROI 10', 'ROI 11', 'ROI 12', 'ROI 13']
# ---> 25 data_filtered = remove_outliers(data, outlier_columns)
#      26
#      27 # 소수점 전처리
#
# <ipython-input-16-8201c0f380b3> in remove_outliers(data, columns, threshold)
#      13
#      14         # 임계값 설정
# ---> 15         lower_threshold = mean - threshold * std
#      16         upper_threshold = mean + threshold * std
#      17
#
# NameError: name 'mean' is not defined

# %%
import pandas as pd
df = pd.read_csv('/UR2 BXPC3 raman raw data__24h.csv')
df


# df라는 이름의 dataframe
decimal_columns = df.columns[0:]  # 소수점 값이 있는 첫번째 열부터 시작

# 소수점 값을 소수점 둘째자리까지 반올
df[decimal_columns] = df[decimal_columns].round(2)

# apply 메소드를 사용해 사용자 정의 반올림 함수 지정 가능
df[decimal_columns] = df[decimal_columns].apply(lambda x: round(x, 2))

# 업데이트 왼 df 출력
#print(df)

df
# Out:
#      Axis [nm]  ROI 1 []  ROI 2 []  ROI 3 []  ROI 4 []  ROI 5 []  ROI 6 []  \
# 0       862.26     10.61     12.63     12.07     11.56     50.60     11.82
# 1       862.46       NaN     12.52     11.76     11.64     11.83     11.59
# 2       862.66     11.25     13.00     12.56     12.21     11.69     12.07
# 3       862.86     11.02     12.76     11.68     11.76     11.92     11.63
# 4       863.06     11.03     12.76     11.80     11.96     12.05     11.64
# ..         ...       ...       ...       ...       ...       ...       ...
# 541     970.40     14.37     14.36     14.68     14.59     15.77     15.07
# 542     970.60     14.25     14.45     14.83     14.55     15.81     14.94
# 543     970.80     14.26     14.48     14.65     14.53     15.83     15.11
# 544     971.00     14.22     14.45     14.93     14.35     15.41     14.92
# 545     971.20     14.53     14.52     15.07     14.71     16.11     15.14
#
# ...

# %% [markdown]
# ---------------------------------------------------------------------------
# 소수점 전처리 후 그래프 출력

# %%
import matplotlib.pyplot as plt
import pandas as pd

import pandas as pd
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')
df

# df라는 이름의 dataframe
decimal_columns = df.columns[0:]  # 소수점 값이 있는 첫번째 열부터 시작

# 소수점 값을 소수점 둘째자리까지 반올
df[decimal_columns] = df[decimal_columns].round(2)

# apply 메소드를 사용해 사용자 정의 반올림 함수 지정 가능
df[decimal_columns] = df[decimal_columns].apply(lambda x: round(x, 2))


# 데이터프레임에서 열 선택
df_selected = df[['Axis [nm]', 'ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']]

# 그래프 그리기
df_selected.plot(x='Axis [nm]', y=['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []'], figsize=(20, 6))

# 그래프 제목 설정
plt.title('Graph of ROIs')

# x축, y축 레이블 설정
plt.xlabel('Axis [nm]')
plt.ylabel('Intensity')

# 범례 추가
plt.legend()

# 그래프 표시
plt.show()

# %% [markdown]
# 주어진 데이터로부터 스펙트럼을 계산. 이를 위해 먼저 데이터프레임에 있는 열의 값을 배열로 변환하고, 이를 사용하여 스펙트럼을 계산

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# df라는 이름의 dataframe
decimal_columns = df.columns[0:]  # 소수점 값이 있는 첫번째 열부터 시작

# 소수점 값을 소수점 둘째자리까지 반올림
df[decimal_columns] = df[decimal_columns].round(2)

# apply 메소드를 사용해 사용자 정의 반올림 함수 지정 가능
df[decimal_columns] = df[decimal_columns].apply(lambda x: round(x, 2))

# 데이터프레임에서 열 선택
df_selected = df[['Axis [nm]', 'ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']]

# 스펙트럼 계산
wavelengths = df_selected['Axis [nm]'].values
intensities = df_selected.drop('Axis [nm]', axis=1).values.sum(axis=1)

# 그래프 그리기
plt.figure(figsize=(20, 6))
plt.plot(wavelengths, intensities)

# 그래프 제목 설정
plt.title('Raman Scattering Spectrum')

# x축, y축 레이블 설정
plt.xlabel('Wavelength [nm]')
plt.ylabel('Intensity')

# 그래프 표시
plt.show()

# 그래프 피크 값 출력
peaks = pd.Series(intensities, index=wavelengths).max()
print("Peak value:", peaks)
# Out:
# Peak value: 644.8700000000001

# %% [markdown]
# <br>
#
# **정규화**
#
# 정규화는 데이터를 일정한 범위로 조정하는 전처리 기법으로 데이터를 정규화하면 각 열의 값을 0과 1 사이 또는 -1과 1 사이로 조정

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# 데이터를 DataFrame 형식으로 변환
data = {
    'Axis [nm]': [916.729650] * 14,
    'ROI 1 []': [20.067004, 20.813750, 21.382249, 20.697220, 22.391101, 21.725776, 20.936489, 20.775449, 20.645484, 19.995003, 19.776193, 20.015165, 19.436598],
    'ROI 2 []': [20.067004, 20.813750, 21.382249, 20.697220, 22.391101, 21.725776, 20.936489, 20.775449, 20.645484, 19.995003, 19.776193, 20.015165, 19.436598],
    'ROI 3 []': [20.067004, 20.813750, 21.382249, 20.697220, 22.391101, 21.725776, 20.936489, 20.775449, 20.645484, 19.995003, 19.776193, 20.015165, 19.436598],
    'ROI 4 []': [20.067004, 20.813750, 21.382249, 20.697220, 22.391101, 21.725776, 20.936489, 20.775449, 20.645484, 19.995003, 19.776193, 20.015165, 19.436598],
    'ROI 5 []': [20.067004, 20.813750, 21.382249, 20.697220, 22.391101, 21.725776, 20.936489, 20.775449, 20.645484, 19.995003, 19.776193, 20.015165, 19.436598],
    'ROI 6 []': [20.067004, 20.813750, 21.382249, 20.697220, 22.391101, 21.725776, 20.936489, 20.775449, 20.645484, 19.995003, 19.776193, 20.015165, 19.436598],
    'ROI 7 []': [20.067004, 20.813750, 21.382249, 20.697220, 22.391101, 21.725776, 20.936489, 20.775449, 20.645484, 19.995003, 19.776193, 20.015165, 19.436598],
    'ROI 8 []': [20.067004, 20.813750, 21.382249, 20.697220, 22.391101, 21.725776, 20.936489, 20.775449, 20.645484, 19.995003, 19.776193, 20.015165, 19.436598],
    'ROI 9 []': [20.067004, 20.813750, 21.382249, 20.697220, 22.391101, 21.725776, 20.936489, 20.775449, 20.645484, 19.995003, 19.776193, 20.015165, 19.436598],
    'ROI 10 []': [20.067004, 20.813750, 21.382249, 20.697220, 22.391101, 21.725776, 20.936489, 20.775449, 20.645484, 19.995003, 19.776193, 20.015165, 19.436598],
    'ROI 11 []': [20.067004, 20.813750, 21.382249, 20.697220, 22.391101, 21.725776, 20.936489, 20.775449, 20.645484, 19.995003, 19.776193, 20.015165, 19.436598],
    'ROI 12 []': [20.067004, 20.813750, 21.382249, 20.697220, 22.391101, 21.725776, 20.936489, 20.775449, 20.645484, 19.995003, 19.776193, 20.015165, 19.436598],
    'ROI 13 []': [20.067004, 20.813750, 21.382249, 20.697220, 22.391101, 21.725776, 20.936489, 20.775449, 20.645484, 19.995003, 19.776193, 20.015165, 19.436598]
}

data = pd.DataFrame(df)

# Min-Max 정규화
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(df.values)

# 정규화된 데이터를 DataFrame으로 변환
normalized_df = pd.DataFrame(normalized_data, columns=df.columns)

print(normalized_df)

normalized_df
# Out:
#      Axis [nm]  ROI 1 []  ROI 2 []  ROI 3 []  ROI 4 []  ROI 5 []  ROI 6 []  \
# 0     0.000000  0.000979  0.014504  0.266035  0.008093  0.938384  0.010013
# 1     0.001836       NaN  0.011603  0.259202  0.010251  0.008871  0.004255
# 2     0.003672  0.016638  0.024262  0.276835  0.025627  0.005514  0.016270
# 3     0.005508  0.011011  0.017932  0.257439  0.013488  0.011029  0.005257
# 4     0.007343  0.011255  0.017932  0.260084  0.018883  0.014145  0.005507
# ..         ...       ...       ...       ...       ...       ...       ...
# 541   0.992657  0.092978  0.060127  0.323562  0.089830  0.103333  0.091364
# 542   0.994492  0.090042  0.062500  0.326868  0.088751  0.104292  0.088110
# 543   0.996328  0.090286  0.063291  0.322901  0.088211  0.104771  0.092365
# 544   0.998164  0.089308  0.062500  0.329072  0.083356  0.094702  0.087610
# 545   1.000000  0.096893  0.064346  0.332158  0.093067  0.111484  0.093116
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Min-Max 정규화
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(df.values)

# 정규화된 데이터를 DataFrame으로 변환
normalized_df = pd.DataFrame(normalized_data, columns=df.columns)

# 데이터프레임에서 열 선택
#df_selected = df[['Axis [nm]', 'ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']]

# 그래프 그리기
df_selected.plot(x='Axis [nm]', y=['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []'], figsize=(20, 6))

# 그래프 제목 설정
plt.title('Graph of ROIs')

# x축, y축 레이블 설정
plt.xlabel('Axis [nm]')
plt.ylabel('Intensity')

# 범례 추가
plt.legend()

# 그래프 표시
plt.show()

# %%
#파일 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

file = '/content/UR2 BXPC3 raman raw data__24h.csv'
df = pd.read_csv(file)

df.head()

#데이터 수 확인
print('전체 데이터 건수 :', len(df))

#결측치 확인
print('칼럼별 결측치 개수')
len(df) - df.count()

#Null값 확인
df.isnull().sum()

#중복값 확인
df.duplicated()

#이상치 확인 함수
def get_outlier(df=None, column=None, weight=1.5):
    # target 값과 상관관계가 높은 열을 우선적으로 진행
    quantile_25 = np.percentile(df[column].values, 25)
    quantile_75 = np.percentile(df[column].values, 75)

    IQR = quantile_75 - quantile_25
    IQR_weight = IQR*weight

    lowest = quantile_25 - IQR_weight
    highest = quantile_75 + IQR_weight

    outlier_idx = df[column][ (df[column] < lowest) | (df[column] > highest) ].index
    return outlier_idx

#이상치 제거
outlier_idx = get_outlier(df=df, column='ROI 13 []', weight=1.5)
df.drop(outlier_idx, axis=0, inplace=True)

#데이터 수 확인
print('전체 데이터 건수 :', len(df))

#이상치 제거 후 그래프
cols = len(df.columns) - 1

df['Axis [nm]'] = df['Axis [nm]'].replace('[\$,]', '', regex=True).astype(float)
x = df['Axis [nm]']

plt.figure(figsize=(15, 8))
for i in range(1,cols+1):
    colName = f'ROI {i} []'
    df[colName] = df[colName].replace('[\$,]', '', regex=True).astype(float)
    y = df[colName]

    plt.plot(x,y,label=colName)
    plt.legend(loc='upper right',frameon=True)
plt.show()

#정규화
ndf = (df - df.min())/(df.max() - df.min())
ndf.head()

#정규화 후 그래프
cols = len(ndf.columns) - 1

ndf['Axis [nm]'] = ndf['Axis [nm]'].replace('[\$,]', '', regex=True).astype(float)
x = ndf['Axis [nm]']

plt.figure(figsize=(15, 8))
for i in range(1,cols+1):
    colName = f'ROI {i} []'
    ndf[colName] = ndf[colName].replace('[\$,]', '', regex=True).astype(float)
    y = ndf[colName]

    plt.plot(x,y,label=colName)
    plt.legend(loc='upper right',frameon=True)
plt.show()
# Out:
# 전체 데이터 건수 : 546
# 칼럼별 결측치 개수
# 전체 데이터 건수 : 508

# %% [markdown]
# ---------------------------------------------------------------------
# 표준화

# %%
import pandas as pd
import numpy as np
from IPython.display import Image
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris


from sklearn.preprocessing import StandardScaler

# CSV 파일 읽기
data = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# 표준화 객체 생성
scaler = StandardScaler()

# 표준화를 적용할 열 선택 (ROI 1 []부터 ROI 13 []까지)
columns_to_standardize = df.columns[1:]

# 선택한 열을 표준화
df[columns_to_standardize] = scaler.fit_transform(df[columns_to_standardize])

iris = load_iris()

x = iris['data']
y = iris['target']

X = x[:,0]

X_= (X-X.mean())/X.std()

# 그래프 그리기
cols = len(df.columns) - 1

plt.figure(figsize=(15, 8))
plt.subplot(1,2,1)
sns.distplot(X, bins=5, color='b')

plt.subplot(1,2,2)
sns.distplot(X_, bins=5, color='r')
plt.title("Standardization", fontsize=16)
plt.show()
# Out:
# <ipython-input-82-4f1537bea04f>:37: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X, bins=5, color='b')
# <ipython-input-82-4f1537bea04f>:40: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_, bins=5, color='r')

# %% [markdown]
# 표준화를 통해 데이터의 스케일을 일정하게 맞추고, 이상치에 덜 민감한 분포로 변환된 것을 확인

# %% [markdown]
# ------------------------------------------------------------
# 데이터 분포 시각화

# %%
import pandas as pd
import numpy as np
from IPython.display import Image
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# CSV 파일 읽기
data = pd.read_csv('/UR2 BXPC3 raman raw data__24h.csv')

# 표준화 객체 생성
scaler = StandardScaler()

# 표준화를 적용할 열 선택 (ROI 1 []부터 ROI 13 []까지)
columns_to_standardize = data.columns[1:]

# 선택한 열을 표준화
data[columns_to_standardize] = scaler.fit_transform(data[columns_to_standardize])

iris = load_iris()

x = iris['data']
y = iris['target']

X = x[:, 0]
X_ = (X - X.mean()) / X.std()

# 그래프 그리기
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.scatterplot(x=X[:50], y=X_[50:100], hue=y[:50], palette='muted')
plt.title('Sepal', fontsize=16)

plt.subplot(1, 2, 2)
sns.scatterplot(x=X[:50], y=X_[50:100], hue=y[:50], palette='muted')
plt.title('Petal', fontsize=16)

plt.show()

# %%
import pandas as pd
import numpy as np
from IPython.display import Image
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# CSV 파일 읽기
data = pd.read_csv('/UR2 BXPC3 raman raw data__24h.csv')

# 표준화 객체 생성
scaler = StandardScaler()

# 표준화를 적용할 열 선택 (ROI 1 []부터 ROI 13 []까지)
columns_to_standardize = data.columns[1:]

# 선택한 열을 표준화
data[columns_to_standardize] = scaler.fit_transform(data[columns_to_standardize])

iris = load_iris()

x = iris['data']
y = iris['target']

X = x[:, :2]  # 첫 번째와 두 번째 열을 선택
X_ = (X - X.mean(axis=0)) / X.std(axis=0)  # 열 별로 표준화

# 그래프 그리기
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.scatterplot(x=X_[:, 0], y=X_[:, 1], hue=y, palette='muted')
plt.title('Sepal', fontsize=16)

X = x[:, 2:]  # 세 번째와 네 번째 열을 선택
X_ = (X - X.mean(axis=0)) / X.std(axis=0)  # 열 별로 표준화

plt.subplot(1, 2, 2)
sns.scatterplot(x=X_[:, 0], y=X_[:, 1], hue=y, palette='muted')
plt.title('Petal', fontsize=16)

plt.show()

# %%
# Baseline stimation with asymmetric least squares
# According to paper: "Baseline Correction with Asymmetric Least Squares Smoothing"
# by Paul H. C. Eilers and Hans F.M. Boelens. October 21, 2005

# https://towardsdatascience.com/data-science-for-raman-spectroscopy-a-practical-example-e81c56cf25f

# We need the following packages here:
from scipy import sparse
from scipy.sparse.linalg import spsolve
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

file = '/content/UR2 BXPC3 raman raw data__24h.csv'
df = pd.read_csv(file)

cols = len(df.columns) - 1
# rows = len(df)

df['Axis [nm]'] = df['Axis [nm]'].replace('[\$,]', '', regex=True).astype(float)
x = df['Axis [nm]']

# for i in range(1,cols+1):
i = 2
colName = f'ROI {i} []'
df[colName] = df[colName].replace('[\$,]', '', regex=True).astype(float)
y = df[colName]

plt.figure()
plt.plot(x,y)
plt.xlabel(df.columns[i])
plt.ylabel(df.columns[0])
plt.axis([860,975,0,55])
plt.title(colName+" "+'Axis')

plt.show()

# Baseline stimation function:
def baseline_als(y, lam, p, niter=100):
    L = len(y)
    D = sparse.diags([1,-2,1],[0,-1,-2], shape=(L,L-2))
    w = np.ones(L)
    for i in range(niter):
        W = sparse.spdiags(w, 0, L, L)
        Z = W + lam * D.dot(D.transpose())
        z = spsolve(Z, w*y)
        w = p * (y > z) + (1-p) * (y < z)
    return z

# For more info see the paper and https://stackoverflow.com/questions/29156532/python-baseline-correction-library

# Parameters for this case:
l = 1000000 # smoothness, baseline을 얼마나 부드럽게 추정할지를 결정. 이 값을 높게 설정하면 데이터의 잡음에 덜 민감한 baseline이 생성될 수 있지만, 실제 baseline의 변화를 덜 반영할 수도 있습니다. chatGPT said..
p = 0.05 # asymmetry. 비대칭성.
# 양쪽으로 비대칭적으로 어떤 정도의 기울기를 허용할지를 결정합니다. 값이 작을수록 추정된 baseline은 더 많은 비대칭성을 가집니다

# Estimation of the baseline:
estimated_baselined = baseline_als(y, l, p)

# Baseline subtraction:
baselined_spectrum = y - estimated_baselined

# How does it look like?
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(16,4))

# We compared the original mix spectrum and the estimated baseline:
ax1.plot(x, y, color = 'black', label = 'Mix spectrum with noise' )
ax1.plot(x, estimated_baselined, color = 'red', label = 'Estimated baseline')
ax1.set_title('Baseline estimation', fontsize = 15)
ax1.set_xlabel('Wavelength', fontsize = 15)
ax1.set_ylabel('Intensity',  fontsize = 15)
ax1.legend()

# We plot the mix spectrum after baseline subtraction
ax2.plot(x, baselined_spectrum, color = 'black', label = 'Baselined spectrum with noise' )
ax2.set_title('Baselined spectrum (original - baseline)', fontsize = 15)
ax2.set_xlabel('Wavelength', fontsize = 15)
ax2.set_ylabel('Intensity',  fontsize = 15)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from peakutils import baseline
import numpy as np
from scipy import sparse
from scipy.sparse.linalg import spsolve

# 데이터프레임에서 열 선택
df_selected = df[['Axis [nm]', 'ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']]

# 그래프 그리기
df_selected.plot(x='Axis [nm]', y=['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []'], figsize=(20, 6))

# 그래프 제목 설정
plt.title('Graph of ROIs')

# x축, y축 레이블 설정
plt.xlabel('Axis [nm]')
plt.ylabel('Intensity')

# 범례 추가
plt.legend()

# Baseline 적용
def baseline_als(y, lam, p, niter=10):
  L = len(y)
  D = sparse.diags([1,-2,1],[0,-1,-2], shape=(L,L-2))
  w = np.ones(L)
  #for문을 이용해 각 열에 대해 baseline 추정 후 그래프로 출력
  for i in range(niter):
    W = sparse.spdiags(w, 0, L, L)
    Z = W + lam * D.dot(D.transpose())
    z = spsolve(Z, w*y)
    w = p * (y > z) + (1-p) * (y < z)
  return z

x = df_selected['Axis [nm]'].values
for column in df_selected.columns[1:]:
    y = df_selected[column].values
    baseline_values = baseline_als(y, lam=10**6, p=0.01, niter=10)  # baseline_als 함수 실행
    plt.plot(x, y - baseline_values, linewidth=1)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from peakutils import baseline
import numpy as np

# 데이터프레임에서 열 선택
df_selected = df[['Axis [nm]', 'ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']]

# 그래프 그리기
df_selected.plot(x='Axis [nm]', y=['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []'], figsize=(20, 6))

# 그래프 제목 설정
plt.title('Graph of ROIs')

# x축, y축 레이블 설정
plt.xlabel('Axis [nm]')
plt.ylabel('Intensity')

# 범례 추가
plt.legend()

# Baseline 적용 및 그래프에 그리기
window_size = 10  # 이동평균의 윈도우 크기
for column in df_selected.columns[1:]:
    y = df_selected[column].values
    baseline_values = pd.Series(y).rolling(window_size, center=True).mean()  # 이동평균 계산
    plt.plot(df_selected['Axis [nm]'], baseline_values, linewidth=1)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from peakutils import baseline
import numpy as np

# 데이터프레임에서 열 선택
df_selected = df[['Axis [nm]', 'ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']]

# 그래프 그리기
df_selected.plot(x='Axis [nm]', y=['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []'], figsize=(20, 6))

# 그래프 제목 설정
plt.title('Graph of ROIs')

# x축, y축 레이블 설정
plt.xlabel('Axis [nm]')
plt.ylabel('Intensity')

# 범례 추가
plt.legend()

# Baseline 적용 및 그래프에 그리기
window_size = 10  # 이동평균의 윈도우 크기
for column in df_selected.columns[1:]:
    y = df_selected[column].values
    baseline_values = pd.Series(y).rolling(window_size, center=True).mean()  # 이동평균 계산

    # 기준선 아래 그래프를 그리기 위한 작업
    peaks = baseline(y)  # 피크점 찾기
    lower_values = np.minimum(y, baseline_values)  # 기준선 아래 값들 계산

    # 피크점 사이의 기준선 그래프를 그리기
    peaks = np.append(peaks, len(y))  # 마지막 피크 뒤의 인덱스 추가
    for i in range(len(peaks) - 1):
        x = df_selected['Axis [nm]'].values[int(peaks[i]):int(peaks[i+1])]  # 인덱스를 정수로 변환하여 슬라이싱
        plt.plot(x, lower_values[int(peaks[i]):int(peaks[i+1])], linewidth=1, color='gray')  # 기준선 그래프를 회색으로 설정

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.signal import savgol_filter

# 데이터프레임에서 열 선택
df_selected = df[['Axis [nm]', 'ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']]

# 그래프 그리기
df_selected.plot(x='Axis [nm]', y=['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []'], figsize=(20, 6))

# 그래프 제목 설정
plt.title('Graph of ROIs')

# x축, y축 레이블 설정
plt.xlabel('Axis [nm]')
plt.ylabel('Intensity')

# 범례 추가
plt.legend()

# Baseline 적용 및 그래프에 그리기
window_size = 11  # Savitzky-Golay 필터 윈도우 크기 (홀수)
poly_order = 3  # Savitzky-Golay 필터 다항식 차수
peak_threshold = 0.05  # 피크를 기준으로한 임계값

for column in df_selected.columns[1:]:
    y = df_selected[column].values

    # Savitzky-Golay 필터를 사용하여 기준선 생성
    baseline_values = savgol_filter(y, window_size, poly_order)

    # 피크 탐색
    peak_indices = np.where(y - baseline_values > peak_threshold)[0]

    # 피크 사이의 기준선 그래프를 생성하여 그리기
    for i in range(len(peak_indices) - 1):
        start_index = peak_indices[i]
        end_index = peak_indices[i+1]

        # 기준선 그래프 생성
        baseline_segment = np.linspace(baseline_values[start_index], baseline_values[end_index], end_index - start_index + 1)

        # 그래프에 기준선 그리기
        plt.plot(df_selected['Axis [nm]'][start_index:end_index+1], baseline_segment, linewidth=1, color='black')

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.signal import savgol_filter

# 데이터프레임에서 열 선택
df_selected = df[['Axis [nm]', 'ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']]

# 그래프 그리기
df_selected.plot(x='Axis [nm]', y=['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []'], figsize=(20, 6))

# 피크 값 계산
peaks = df_selected.max()

# 평평한 baseline 계산
baseline = np.mean(peaks)  # 기준값은 피크 값들의 평균으로 설정

# 평활화(Smoothing) 처리
window_length = min(len(df_selected) - 1, len(df_selected.columns))  # 윈도우 크기를 데이터 크기에 맞게 조정
smoothed = savgol_filter(df_selected, window_length=window_length, polyorder=2, mode='interp', axis=0)

# 평평한 baseline을 그래프에 적용하여 그래프를 내리기
df_selected_baseline = df_selected - (smoothed - baseline)
df_selected_baseline.plot(x='Axis [nm]', y=['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []'], figsize=(20, 6))

# 그래프 제목 설정
plt.title('Graph of ROIs with Baseline')

# x축, y축 레이블 설정
plt.xlabel('Axis [nm]')
plt.ylabel('Intensity')

# 범례 추가
plt.legend()

# 그래프 표시
plt.show()

# %%
import numpy as np
from scipy.signal import savgol_filter

# 데이터프레임에서 열 선택
df_selected = df[['Axis [nm]', 'ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']]

# Baseline 보정 함수 정의
def baseline_correction(y, window_length, poly_order):
    # Savitzky-Golay 필터링을 통한 부드러운 baseline 추정
    baseline = savgol_filter(y, window_length, poly_order)

    # 원본 데이터에서 baseline을 빼줌으로써 보정된 spectrum 계산
    corrected_spectrum = y - baseline

    return corrected_spectrum

# 그래프 그리기
fig, ax = plt.subplots(figsize=(20, 6))

# Baseline 보정된 spectrum 그리기
for column in df_selected.columns[1:]:
    x = df_selected['Axis [nm]']
    y = df_selected[column]

    # Baseline 보정 수행
    corrected_spectrum = baseline_correction(y, window_length=11, poly_order=2)

    # 그래프에 그리기
    ax.plot(x, corrected_spectrum, label=column)

# 그래프 제목 설정
ax.set_title('Baseline Corrected Raman Spectrum')

# x축, y축 레이블 설정
ax.set_xlabel('Axis [nm]')
ax.set_ylabel('Intensity')

# 범례 추가
ax.legend()

# 그래프 표시
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-69afb49fb54b> in <cell line: 21>()
#      24
#      25     # Baseline 보정 수행
# ---> 26     corrected_spectrum = baseline_correction(y, window_length=11, poly_order=2)
#      27
#      28     # 그래프에 그리기
#
# <ipython-input-67-69afb49fb54b> in baseline_correction(y, window_length, poly_order)
#       8 def baseline_correction(y, window_length, poly_order):
#       9     # Savitzky-Golay 필터링을 통한 부드러운 baseline 추정
# ---> 10     baseline = savgol_filter(y, window_length, poly_order)
#      11
#      12     # 원본 데이터에서 baseline을 빼줌으로써 보정된 spectrum 계산
#
# /usr/local/lib/python3.10/dist-packages/scipy/signal/_savitzky_golay.py in savgol_filter(x, window_length, polyorder, deriv, delta, axis, mode, cval)
#     343     if mode == "interp":
#     344         if window_length > x.shape[axis]:
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.interpolate import CubicSpline
from scipy import sparse
from scipy.sparse import linalg
from numpy.linalg import norm

def baseline_arPLS(y, ratio=1e-6, lam=100, niter=10, full_output=False):
    L = len(y)

    diag = np.ones(L - 2)
    D = sparse.spdiags([diag, -2*diag, diag], [0, -1, -2], L, L - 2)

    H = lam * D.dot(D.T)

    w = np.ones(L)
    W = sparse.spdiags(w, 0, L, L)

    crit = 1
    count = 0

    while crit > ratio:
        z = linalg.spsolve(W + H, W * y)
        d = y - z
        dn = d[d < 0]

        m = np.mean(dn)
        s = np.std(dn)

        w_new = 1 / (1 + np.exp(2 * (d - (2*s - m))/s))

        crit = norm(w_new - w) / norm(w)

        w = w_new
        W.setdiag(w)

        count += 1

        if count > niter:
            print('Maximum number of iterations exceeded')
            break

    if full_output:
        info = {'num_iter': count, 'stop_criterion': crit}
        return z, d, info
    else:
        return z

def spectra_model(x):
    coeff = np.array([100, 200, 100])
    mean = np.array([300, 750, 800])
    stdv = np.array([15, 30, 15])

    terms = []
    for ind in range(len(coeff)):
        term = coeff[ind] * np.exp(-((x - mean[ind]) / stdv[ind])**2)
        terms.append(term)

    spectra = sum(terms)
    return spectra

x_vals = np.arange(1, 1001)
spectra_sim = spectra_model(x_vals)

x_poly = np.array([0, 250, 700, 1000])
y_poly = np.array([200, 180, 230, 200])
poly = CubicSpline(x_poly, y_poly)
baseline = poly(x_vals)

noise = np.random.randn(len(x_vals)) * 0.1
spectra_base = spectra_sim + baseline + noise

# Baseline 보정 함수 정의
def baseline_correction(y):
    _, corrected_spectrum, _ = baseline_arPLS(y, lam=1e4, niter=10, full_output=True)
    return corrected_spectrum

# 데이터프레임 생성
df = pd.DataFrame({'Axis [nm]': x_vals, 'Spectrum': spectra_base})

# Baseline 보정 수행
df['Corrected Spectrum'] = baseline_correction(df['Spectrum'])

# 그래프 그리기
fig, ax = plt.subplots(figsize=(10, 6))

# 원본 스펙트럼 그리기
ax.plot(df['Axis [nm]'], df['Spectrum'], label='Original Spectrum')

# 보정된 스펙트럼 그리기
ax.plot(df['Axis [nm]'], df['Corrected Spectrum'], label='Baseline Corrected Spectrum')

# 그래프 제목 설정
ax.set_title('Baseline Correction')

#그래프 축 레이블 설정
ax.set_xlabel('Axis [nm]')
ax.set_ylabel('Intensity')


#범례 추가
ax.legend()

#그래프 표시
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Maximum number of iterations exceeded

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.interpolate import CubicSpline
from scipy import sparse
from scipy.sparse import linalg
from numpy.linalg import norm

import pandas as pd
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')
df



# 데이터프레임에서 열 선택
df_selected = df[['Axis [nm]']]

# 그래프 그리기
df_selected.plot(x='Axis [nm]', figsize=(10, 6))

# 그래프 제목 설정
plt.title('Baseline Correction')

# x축, y축 레이블 설정
plt.xlabel('Axis [nm]')
plt.ylabel('Intensity')

# 범례 추가
plt.legend()

# 그래프 표시
plt.show()


def baseline_arPLS(y, ratio=1e-6, lam=100, niter=10, full_output=False):
    L = len(y)

    diag = np.ones(L - 2)
    D = sparse.spdiags([diag, -2*diag, diag], [0, -1, -2], L, L - 2)

    H = lam * D.dot(D.T)

    w = np.ones(L)
    W = sparse.spdiags(w, 0, L, L)

    crit = 1
    count = 0

    while crit > ratio:
        z = linalg.spsolve(W + H, W * y)
        d = y - z
        dn = d[d < 0]

        m = np.mean(dn)
        s = np.std(dn)

        w_new = 1 / (1 + np.exp(2 * (d - (2*s - m))/s))

        crit = norm(w_new - w) / norm(w)

        w = w_new
        W.setdiag(w)

        count += 1

        if count > niter:
            print('Maximum number of iterations exceeded')
            break

    if full_output:
        info = {'num_iter': count, 'stop_criterion': crit}
        return z, d, info
    else:
        return z

def spectra_model(x):
    coeff = np.array([100, 200, 100])
    mean = np.array([300, 750, 800])
    stdv = np.array([15, 30, 15])

    terms = []
    for ind in range(len(coeff)):
        term = coeff[ind] * np.exp(-((x - mean[ind]) / stdv[ind])**2)
        terms.append(term)

    spectra = sum(terms)
    return spectra

x_vals = np.arange(1, 1001)
spectra_sim = spectra_model(x_vals)

x_poly = np.array([0, 250, 700, 1000])
y_poly = np.array([200, 180, 230, 200])
poly = CubicSpline(x_poly, y_poly)
baseline = poly(x_vals)

noise = np.random.randn(len(x_vals)) * 0.1
spectra_base = spectra_sim + baseline + noise

# Baseline 보정 함수 정의
def baseline_correction(y):
    _, corrected_spectrum, _ = baseline_arPLS(y, lam=1e4, niter=10, full_output=True)
    return corrected_spectrum

# 데이터프레임 생성
df = pd.DataFrame({'Axis [nm]': x_vals, 'Spectrum': spectra_base})

# Baseline 보정 수행
df['Corrected Spectrum'] = baseline_correction(df['Spectrum'])

# 그래프 그리기
fig, ax = plt.subplots(figsize=(10, 6))

# 원본 스펙트럼 그리기
ax.plot(df['Axis [nm]'], df['Spectrum'], label='Original Spectrum')

# 보정된 스펙트럼 그리기
# ax.plot(df['Axis [nm]'], df['Corrected Spectrum'], label='Baseline Corrected Spectrum')

# 그래프 제목 설정
ax.set_title('Baseline Correction')

#그래프 축 레이블 설정
ax.set_xlabel('Axis [nm]')
ax.set_ylabel('Intensity')

#범례 추가
ax.legend()

#그래프 표시
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Maximum number of iterations exceeded
