# %%
import matplotlib.pyplot as plt
import pandas as pd

import pandas as pd
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')
df

# df라는 이름의 dataframe
decimal_columns = df.columns[0:]  # 소수점 값이 있는 첫번째 열부터 시작

# 소수점 값을 소수점 둘째자리까지 반올림
df[decimal_columns] = df[decimal_columns].round(2)

# apply 메소드를 사용해 사용자 정의 반올림 함수 지정 가능
df[decimal_columns] = df[decimal_columns].apply(lambda x: round(x, 2))


# 데이터프레임에서 열 선택
df_selected = df[['Axis [nm]', 'ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']]

# 그래프 그리기
df_selected.plot(x='Axis [nm]', y=['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []'], figsize=(20, 6))

# 그래프 제목 설정
plt.title('Graph of ROIs')

# x축, y축 레이블 설정
plt.xlabel('Axis [nm]')
plt.ylabel('Intensity')

# 범례 추가
plt.legend()

# 그래프 표시
plt.show()

# 그래프 피크 값 출력
peaks = df_selected.max()
print("Peak values:", peaks)
# Out:
# Peak values: Axis [nm]    971.20
# ROI 1 []      51.44
# ROI 2 []      50.00
# ROI 3 []      45.37
# ROI 4 []      48.33
# ROI 5 []      53.17
# ROI 6 []      51.37
# ROI 7 []      51.47
# ROI 8 []      48.92
# ROI 9 []      47.74
# ROI 10 []     49.29
# ROI 11 []     46.67
# ROI 12 []     53.57
# ROI 13 []     48.15
# dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# df라는 이름의 dataframe
decimal_columns = df.columns[0:]  # 소수점 값이 있는 첫번째 열부터 시작

# 소수점 값을 소수점 둘째자리까지 반올림
df[decimal_columns] = df[decimal_columns].round(2)

# apply 메소드를 사용해 사용자 정의 반올림 함수 지정 가능
df[decimal_columns] = df[decimal_columns].apply(lambda x: round(x, 2))
# 관심 영역 선택 (ROI)
roi_columns = df.columns[df.columns.str.startswith('ROI')]
roi_data = df[roi_columns]

# 스펙트럼 계산
wavelengths = df_selected['Axis [nm]'].values
intensities = df_selected.drop('Axis [nm]', axis=1).values.sum(axis=1)

# 그래프 그리기
plt.figure(figsize=(20, 6))
plt.plot(wavelengths, intensities)

# 그래프 제목 설정
plt.title('Raman Scattering Spectrum')

# x축, y축 레이블 설정
plt.xlabel('Wavelength [nm]')
plt.ylabel('Intensity')

# 그래프 표시
plt.show()

# 그래프 피크 값 출력
peaks = pd.Series(intensities, index=wavelengths).max()
print("Peak value:", peaks)
# Out:
# Peak value: 644.8700000000001

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# df라는 이름의 dataframe
decimal_columns = df.columns[0:]  # 소수점 값이 있는 첫번째 열부터 시작

# 소수점 값을 소수점 둘째자리까지 반올림
df[decimal_columns] = df[decimal_columns].round(2)

# apply 메소드를 사용해 사용자 정의 반올림 함수 지정 가능
df[decimal_columns] = df[decimal_columns].apply(lambda x: round(x, 2))
# 관심 영역 선택 (ROI)
roi_columns = df.columns[df.columns.str.startswith('ROI')]
roi_data = df[roi_columns]

# 스펙트럼 계산
wavelengths = df_selected['Axis [nm]'].values
intensities = df_selected.drop('Axis [nm]', axis=1).values.sum(axis=1)

# Fitting a third-order polynomial curve
coefficients = np.polyfit(wavelengths, intensities, 3)
fitted_curve = np.polyval(coefficients, wavelengths)

# 그래프 그리기
plt.figure(figsize=(20, 6))
plt.plot(wavelengths, intensities, label='Original Data')
plt.plot(wavelengths, fitted_curve, label='Fitted Curve')

# 그래프 제목 설정
plt.title('Raman Scattering Spectrum')

# x축, y축 레이블 설정
plt.xlabel('Wavelength [nm]')
plt.ylabel('Intensity')

# 범례 표시
plt.legend()

# 그래프 표시
plt.show()

# 그래프 피크 값 출력
peaks = pd.Series(intensities, index=wavelengths).max()
print("Peak value:", peaks)
# Out:
# Peak value: 644.8700000000001

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# df라는 이름의 dataframe
decimal_columns = df.columns[0:]  # 소수점 값이 있는 첫번째 열부터 시작

# 소수점 값을 소수점 둘째자리까지 반올림
df[decimal_columns] = df[decimal_columns].round(2)

# apply 메소드를 사용해 사용자 정의 반올림 함수 지정 가능
df[decimal_columns] = df[decimal_columns].apply(lambda x: round(x, 2))

# 데이터프레임에서 열 선택
df_selected = df[['Axis [nm]', 'ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']]

# 스펙트럼 계산
wavelengths = df_selected['Axis [nm]'].values
intensities = df_selected.drop('Axis [nm]', axis=1).values.sum(axis=1)

# Selecting the range to fit
mask = (wavelengths >= 900) & (wavelengths <= 920)
fit_wavelengths = wavelengths[mask]
fit_intensities = intensities[mask]

# Fitting a third-order polynomial curve to the selected range
coefficients = np.polyfit(fit_wavelengths, fit_intensities, 3)
fitted_curve = np.polyval(coefficients, fit_wavelengths)

# Plotting the original data
plt.figure(figsize=(20, 6))
plt.plot(wavelengths, intensities, label='Original Data')

# Plotting the fitted curve within the specified range
plt.plot(fit_wavelengths, fitted_curve, label='Fitted Curve')

# 그래프 제목 설정
plt.title('Raman Scattering Spectrum')

# x축, y축 레이블 설정
plt.xlabel('Wavelength [nm]')
plt.ylabel('Intensity')

# 범례 표시
plt.legend()

# 그래프 표시
plt.show()

# 그래프 피크 값 출력
peaks = pd.Series(intensities, index=wavelengths).max()
print("Peak value:", peaks)
# Out:
# Peak value: 644.8700000000001

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import rampy

# df라는 이름의 dataframe
decimal_columns = df.columns[0:]  # 소수점 값이 있는 첫번째 열부터 시작

# 소수점 값을 소수점 둘째자리까지 반올림
df[decimal_columns] = df[decimal_columns].round(2)

# apply 메소드를 사용해 사용자 정의 반올림 함수 지정 가능
df[decimal_columns] = df[decimal_columns].apply(lambda x: round(x, 2))

# 데이터프레임에서 열 선택
df_selected = df[['Axis [nm]', 'ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']]

# 스펙트럼 계산
wavelengths = df_selected['Axis [nm]'].values
intensities = df_selected.drop('Axis [nm]', axis=1).values.sum(axis=1)

# need to define some fitting regions for the spline
roi = np.array([[900, 920]])

# Fitting the data using different baseline estimation methods
ycalc_poly, base_poly = rampy.baseline(wavelengths, intensities, roi, 'poly', polynomial_order=3)
ycalc_gcvspl, base_gcvspl = rampy.baseline(wavelengths, intensities, roi, 'gcvspline', s=0.1)
ycalc_uni, base_uni = rampy.baseline(wavelengths, intensities, roi, 'unispline', s=1e0)
ycalc_als, base_als = rampy.baseline(wavelengths, intensities, roi, 'als', lam=10**5, p=0.05)
ycalc_arpls, base_arpsl = rampy.baseline(wavelengths, intensities, roi, 'arPLS', lam=10**6, ratio=0.001)
ycalc_drpls, base_drpsl = rampy.baseline(wavelengths, intensities, roi, 'drPLS')
ycalc_rubberband, base_rubberband = rampy.baseline(wavelengths, intensities, roi, 'rubberband')

# Plotting the original data and the fitted curves
plt.figure(figsize=(20, 6))
plt.plot(wavelengths, intensities, label="Raw Data")
plt.plot(wavelengths, base_poly, "-", color="grey", label="polynomial")
plt.plot(wavelengths, base_uni, "b-", label="unispline baseline")
plt.plot(wavelengths, base_gcvspl, "-", color="orange", label="gcvspline baseline")
plt.plot(wavelengths, base_als, ":", color="purple", label="als baseline")
plt.plot(wavelengths, base_arpsl, "-.", color="cyan", label="arPLS baseline")
plt.plot(wavelengths, base_drpsl, "--", color="orange", label="drPLS baseline")
plt.plot(wavelengths, base_rubberband, "--", color="green", label="rubberband baseline")

# 그래프 제목 설정
plt.title('Raman Scattering Spectrum with Fitted Baselines')

# x축, y축 레이블 설정
plt.xlabel('Wavelength [nm]')
plt.ylabel('Intensity')

# 범례 표시
plt.legend()

# 그래프 표시
plt.show()

# 그래프 피크 값 출력
peaks = pd.Series(intensities, index=wavelengths).max()
print("Peak value:", peaks)
# Out:
# Peak value: 644.8700000000001

# %%
pip install rampy
# Out:
# Collecting rampy
#   Downloading rampy-0.4.9-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.10/dist-packages (from rampy) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from rampy) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from rampy) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from rampy) (1.5.3)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (from rampy) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rampy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rampy) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->rampy) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->rampy) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->rampy) (1.16.0)
# Installing collected packages: rampy
# Successfully installed rampy-0.4.9

# %%
pip install gcvspline
# Out:
# Collecting gcvspline
#   Downloading gcvspline-0.4.tar.gz (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.1/167.1 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: gcvspline
#   Building wheel for gcvspline (setup.py) ... done
#   Created wheel for gcvspline: filename=gcvspline-0.4-cp310-cp310-linux_x86_64.whl size=155788 sha256=d6f72a5c10841989d159be27fab6b7d7bc42e86882f2d3777de1710216dc6a51
#   Stored in directory: /root/.cache/pip/wheels/33/76/79/aa119386f2e53dddea85925d60f579c0be24a58a466692708c
# Successfully built gcvspline
# Installing collected packages: gcvspline
# Successfully installed gcvspline-0.4

# %%
pip install gcvspline
# Out:
# Requirement already satisfied: gcvspline in /usr/local/lib/python3.10/dist-packages (0.4)

# %%
import numpy as np
import matplotlib.pyplot as plt
import rampy

# Creating a signal
nb_points = 500
x = np.linspace(50, 500, nb_points)

# Gaussian peaks
p1 = 20.0 * np.exp(-np.log(2) * ((x-150.0)/15.0)**2)
p2 = 100.0 * np.exp(-np.log(2) * ((x-250.0)/5.0)**2)
p3 = 50.0 * np.exp(-np.log(2) * ((x-450.0)/1.0)**2)
p4 = 20.0 * np.exp(-np.log(2) * ((x-350.0)/30.0)**2)
p5 = 30.0 * np.exp(-np.log(2) * ((x-460.0)/5.0)**2)

# Background: a large sin distortion + linear
bkg = 10*np.sin(x/50) + 0.1*x

# Noise
noise = 2.0 * np.random.normal(size=nb_points)

# Observation
y = p1 + p2 + p3 + p4 + p5 + noise + bkg

# Define fitting regions for the spline
roi = np.array([[0, 100], [200, 220], [280, 290], [420, 430], [480, 500]])

# Calculating the baselines
base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
base_gcvspl = rampy.baseline(x, y, roi, 'gcvspline', s=0.1)
base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
base_als = rampy.baseline(x, y, roi, 'als', lam=10**5, p=0.05)
base_arpsl = rampy.baseline(x, y, roi, 'arPLS', lam=10**6, ratio=0.001)
base_drpsl = rampy.baseline(x, y, roi, 'drPLS')
base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# Plotting the original data and the fitted baselines
plt.figure(dpi=150)
plt.plot(x, y, "k-", label="Raw Data")
plt.plot(x, base_poly, "-", color="grey", label="Polynomial")
plt.plot(x, base_uni, "b-", label="Unispline Baseline")
plt.plot(x, base_gcvspl, "-", color="orange", label="GCVSpline Baseline")
plt.plot(x, base_als, ":", color="purple", label="ALS Baseline")
plt.plot(x, base_arpsl, "-.", color="cyan", label="arPLS Baseline")
plt.plot(x, base_drpsl, "--", color="orange", label="drPLS Baseline")
plt.plot(x, base_rubberband, "--", color="green", label="Rubberband Baseline")

plt.xlabel("X")
plt.ylabel("Y")

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-f5cfc3489d93> in <cell line: 40>()
#      38 plt.figure(dpi=150)
#      39 plt.plot(x, y, "k-", label="Raw Data")
# ---> 40 plt.plot(x, base_poly, "-", color="grey", label="Polynomial")
#      41 plt.plot(x, base_uni, "b-", label="Unispline Baseline")
#      42 plt.plot(x, base_gcvspl, "-", color="orange", label="GCVSpline Baseline")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689         for line in lines:
#    1690             self.add_line(line)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     309                 this += args[0],
#     310                 args = args[1:]
# --> 311             yield from self._plot_args(
#     312                 this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     313
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     502
#     503         if x.shape[0] != y.shape[0]:
# --> 504             raise ValueError(f"x and y must have same first dimension, but "
#     505                              f"have shapes {x.shape} and {y.shape}")
#     506         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (500,) and (2, 500, 1)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import rampy

# 데이터 불러오기
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# 소수점 자릿수 반올림
decimal_columns = df.columns[0:]
df[decimal_columns] = df[decimal_columns].round(2)

# 데이터프레임에서 필요한 열 선택
df_selected = df[['Axis [nm]', 'ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']]

# 그래프 그리기
df_selected.plot(x='Axis [nm]', y=['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []'], figsize=(20, 6))

# 그래프 제목 설정
plt.title('ROIs 그래프')

# x축, y축 레이블 설정
plt.xlabel('Axis [nm]')
plt.ylabel('Intensity')

# 범례 추가
plt.legend()

# 기준선 추정을 위한 데이터 생성
nb_points = 500
x = np.linspace(50, 500, nb_points)

# 가우시안 피크
p1 = 20.0 * np.exp(-np.log(2) * ((x-150.0)/15.0)**2)
p2 = 100.0 * np.exp(-np.log(2) * ((x-250.0)/5.0)**2)
p3 = 50.0 * np.exp(-np.log(2) * ((x-450.0)/1.0)**2)
p4 = 20.0 * np.exp(-np.log(2) * ((x-350.0)/30.0)**2)
p5 = 30.0 * np.exp(-np.log(2) * ((x-460.0)/5.0)**2)

# 배경: 큰 사인 왜곡 + 선형
bkg = 10*np.sin(x/50) + 0.1*x

# 잡음
noise = 2.0 * np.random.normal(size=nb_points)

# 관측 데이터
y = p1 + p2 + p3 + p4 + p5 + noise + bkg

# 기준선 추정을 위한 구간 설정
roi = np.array([[0, 100], [200, 220], [280, 290], [420, 430], [480, 500]])

# 기준선 추정
ycalc_poly, base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
ycalc_gcvspl, base_gcvspl = rampy.baseline(x, y, roi, 'gcvspline', s=0.1)  # gcvspline 설치시 활성화
ycalc_uni, base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
ycalc_als, base_als = rampy.baseline(x, y, roi, 'als', lam=10**5, p=0.05)
ycalc_arpls, base_arpsl = rampy.baseline(x, y, roi, 'arPLS', lam=10**6, ratio=0.001)
ycalc_drpls, base_drpsl = rampy.baseline(x, y, roi, 'drPLS')
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 그래프 그리기
plt.figure(figsize=(20, 6))
df_selected = df[['Axis [nm]', 'ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']]


# 기준선 그래프 추가
plt.plot(x, base_poly, "-", color="grey", label="다항식 기준선")
plt.plot(x, base_uni, "b-", label="유니스플라인 기준선")
plt.plot(x, base_gcvspl, "-", color="orange", label="GCV스플라인 기준선")  # gcvspline 설치시 활성화
plt.plot(x, base_als, ":", color="purple", label="ALS 기준선")
plt.plot(x, base_arpsl, "-.", color="cyan", label="arPLS 기준선")
plt.plot(x, base_drpsl, "--", color="orange", label="drPLS 기준선")
plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")

# 그래프 표시
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import rampy

# Read the data from the CSV file
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# Round the decimal values in the dataframe
decimal_columns = df.columns[0:]
df[decimal_columns] = df[decimal_columns].round(2)
df[decimal_columns] = df[decimal_columns].apply(lambda x: round(x, 2))

# Select the desired columns for plotting
df_selected = df[['Axis [nm]', 'ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']]

# Extract the wavelength values and intensities
wavelengths = df_selected['Axis [nm]'].values
intensities = df_selected.drop('Axis [nm]', axis=1).values.sum(axis=1)

# Define the fitting regions for the baseline estimation
roi = np.array([[0, 100], [200, 220], [280, 290], [420, 430], [480, 500]])

# Estimate the baselines using different methods
ycalc_poly, base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
ycalc_gcvspl, base_gcvspl = rampy.baseline(x, y, roi, 'gcvspline', s=0.1)  # gcvspline 설치시 활성화
ycalc_uni, base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
ycalc_als, base_als = rampy.baseline(x, y, roi, 'als', lam=10**5, p=0.05)
ycalc_arpls, base_arpsl = rampy.baseline(x, y, roi, 'arPLS', lam=10**6, ratio=0.001)
ycalc_drpls, base_drpsl = rampy.baseline(x, y, roi, 'drPLS')
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# Plot the original data and the baselines
plt.figure(figsize=(20, 6))
plt.plot(wavelengths, intensities, label="Raw Data")
plt.plot(wavelengths, np.squeeze(base_poly), "-", color="grey", label="Polynomial Baseline")

plt.plot(wavelengths, base_uni, "b-", label="Unispline Baseline")
plt.plot(wavelengths, base_gcvspl, "-", color="orange", label="GCVSpline Baseline")
plt.plot(wavelengths, base_als, ":", color="purple", label="ALS Baseline")
plt.plot(wavelengths, base_arpsl, "-.", color="cyan", label="arPLS Baseline")
plt.plot(wavelengths, base_drpsl, "--", color="orange", label="drPLS Baseline")
plt.plot(wavelengths, base_rubberband, "--", color="green", label="Rubberband Baseline")

print(df.shape)  # 데이터프레임의 크기 출력
print(df.head())  # 데이터프레임의 처음 몇 개 행 출력


# Set the plot title, x-label, and y-label
plt.title('Raman Scattering Spectrum with Fitted Baselines')
plt.xlabel('Wavelength [nm]')
plt.ylabel('Intensity')

# Add a legend to the plot
plt.legend()

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-a698943624d1> in <cell line: 36>()
#      34 plt.figure(figsize=(20, 6))
#      35 plt.plot(wavelengths, intensities, label="Raw Data")
# ---> 36 plt.plot(wavelengths, np.squeeze(base_poly), "-", color="grey", label="Polynomial Baseline")
#      37
#      38 plt.plot(wavelengths, base_uni, "b-", label="Unispline Baseline")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689         for line in lines:
#    1690             self.add_line(line)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     309                 this += args[0],
#     310                 args = args[1:]
# --> 311             yield from self._plot_args(
#     312                 this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     313
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     502
#     503         if x.shape[0] != y.shape[0]:
# --> 504             raise ValueError(f"x and y must have same first dimension, but "
#     505                              f"have shapes {x.shape} and {y.shape}")
#     506         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (546,) and (500,)

# %%
import numpy as np
import scipy
from matplotlib import pyplot as plt
import rampy
from sklearn import preprocessing

# 데이터 생성
nb_points = 500
x = np.linspace(50, 500, nb_points)

# 가우시안 피크
p1 = 20.0 * np.exp(-np.log(2) * ((x-150.0)/15.0)**2)
p2 = 100.0 * np.exp(-np.log(2) * ((x-250.0)/5.0)**2)
p3 = 50.0 * np.exp(-np.log(2) * ((x-450.0)/1.0)**2)
p4 = 20.0 * np.exp(-np.log(2) * ((x-350.0)/30.0)**2)
p5 = 30.0 * np.exp(-np.log(2) * ((x-460.0)/5.0)**2)

# 배경: 큰 사인 왜곡 + 선형
bkg = 10*np.sin(x/50) + 0.1*x

# 잡음
noise = 2.0 * np.random.normal(size=nb_points)

# 관측 데이터
y = p1 + p2 + p3 + p4 + p5 + noise + bkg

# 그래프 그리기
plt.plot(x, y, "r-")

# 기준선 추정을 위한 구간 설정
roi = np.array([[0, 100], [200, 220], [280, 290], [420, 430], [480, 500]])

# 기준선 추정
ycalc_poly, base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
ycalc_gcvspl, base_gcvspl = rampy.baseline(x, y, roi, 'gcvspline', s=0.1)  # gcvspline 설치시 활성화
ycalc_uni, base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
ycalc_als, base_als = rampy.baseline(x, y, roi, 'als', lam=10**5, p=0.05)
ycalc_arpls, base_arpsl = rampy.baseline(x, y, roi, 'arPLS', lam=10**6, ratio=0.001)
ycalc_drpls, base_drpsl = rampy.baseline(x, y, roi, 'drPLS')
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 그래프 그리기
plt.figure(dpi=150)
plt.plot(x, y, "k-", label="Raw")
plt.plot(x, bkg, "r-", label="True background")

plt.plot(x, base_poly, "-", color="grey", label="다항식 기준선")
plt.plot(x, base_uni, "b-", label="유니스플라인 기준선")
plt.plot(x, base_gcvspl, "-", color="orange", label="GCV스플라인 기준선")  # gcvspline 설치시 활성화
plt.plot(x, base_als, ":", color="purple", label="ALS 기준선")
plt.plot(x, base_arpsl, "-.", color="cyan", label="arPLS 기준선")
plt.plot(x, base_drpsl, "--", color="orange", label="drPLS 기준선")
plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")

plt.xlabel("X")
plt.ylabel("Y")

plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54637 (\N{HANGUL SYLLABLE HANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45768 (\N{HANGUL SYLLABLE NI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47084 (\N{HANGUL SYLLABLE REO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48180 (\N{HANGUL SYLLABLE BAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import rampy

# Read the data from the CSV file
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# Round the decimal values in the dataframe
decimal_columns = df.columns[0:]
df[decimal_columns] = df[decimal_columns].round(2)
df[decimal_columns] = df[decimal_columns].apply(lambda x: round(x, 2))

# Select the desired columns for plotting
df_selected = df[['Axis [nm]', 'ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']]

# Extract the wavelength values and intensities
wavelengths = df_selected['Axis [nm]'].values
intensities = df_selected.drop('Axis [nm]', axis=1).values

# Define the fitting regions for the baseline estimation
roi = np.array([[0, 100], [200, 220], [280, 290], [420, 430], [480, 500]])

# Estimate the baselines using different methods
base_poly = rampy.baseline(wavelengths, intensities, roi, 'poly', polynomial_order=1)
base_gcvspl = rampy.baseline(wavelengths, intensities, roi, 'gcvspline', s=0.1)
base_uni = rampy.baseline(wavelengths, intensities, roi, 'unispline', s=1e0)
base_als = rampy.baseline(wavelengths, intensities, roi, 'als', lam=10**5, p=0.05)
base_arpls = rampy.baseline(wavelengths, intensities, roi, 'arPLS', lam=10**6, ratio=0.001)
base_drpls = rampy.baseline(wavelengths, intensities, roi, 'drPLS')
base_rubberband = rampy.baseline(wavelengths, intensities, roi, 'rubberband')

# Plot the original data and the baselines
plt.figure(figsize=(20, 6))
plt.plot(wavelengths, intensities[:, 0], label="ROI 1")
plt.plot(wavelengths, np.squeeze(base_poly[:, 0]), "-", color="grey", label="Polynomial Baseline")
plt.plot(wavelengths, np.squeeze(base_uni[:, 0]), "b-", label="Unispline Baseline")
plt.plot(wavelengths, np.squeeze(base_gcvspl[:, 0]), "-", color="orange", label="GCVSpline Baseline")
plt.plot(wavelengths, np.squeeze(base_als[:, 0]), ":", color="purple", label="ALS Baseline")
plt.plot(wavelengths, np.squeeze(base_arpls[:, 0]), "-.", color="cyan", label="arPLS Baseline")
plt.plot(wavelengths, np.squeeze(base_drpls[:, 0]), "--", color="orange", label="drPLS Baseline")
plt.plot(wavelengths, np.squeeze(base_rubberband[:, 0]), "--", color="green", label="Rubberband Baseline")

# Set the plot title, x-label, and y-label
plt.title('Raman Scattering Spectrum with Fitted Baselines')
plt.xlabel('Wavelength [nm]')
plt.ylabel('Intensity')

# Add a legend to the plot
plt.legend()

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-ffddb01a26b5> in <cell line: 25>()
#      23
#      24 # Estimate the baselines using different methods
# ---> 25 base_poly = rampy.baseline(wavelengths, intensities, roi, 'poly', polynomial_order=1)
#      26 base_gcvspl = rampy.baseline(wavelengths, intensities, roi, 'gcvspline', s=0.1)
#      27 base_uni = rampy.baseline(wavelengths, intensities, roi, 'unispline', s=1e0)
#
# /usr/local/lib/python3.10/dist-packages/rampy/baseline.py in baseline(x_input, y_input, bir, method, **kwargs)
#     103     """
#     104     # we get the signals in the bir
# --> 105     yafit_unscaled = get_portion_interest(x_input,y_input,bir)
#     106
#     107     # signal standard standardization with sklearn
#
# /usr/local/lib/python3.10/dist-packages/rampy/baseline.py in get_portion_interest(x, y, bir)
#      32     birlen = np.array(bir.shape[0])
#      33
# ---> 34     sp = np.transpose(np.vstack((x.reshape(-1),y.reshape(-1))))
#      35     ### selection of bir data
#      36     for i in range(birlen):
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in vstack(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/shape_base.py in vstack(tup)
#     280     if not isinstance(arrs, list):
#     281         arrs = [arrs]
# --> 282     return _nx.concatenate(arrs, 0)
#     283
#     284
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 546 and the array at index 1 has size 7098

# %%
import numpy as np
import rampy
from matplotlib import pyplot as plt

# 데이터 로드
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = ['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1)

# 기준선 추정을 위한 구간 설정
roi = np.array([[min(x), max(x)]])

# 기준선 추정
ycalc_poly, base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
ycalc_gcvspl, base_gcvspl = rampy.baseline(x, y, roi, 'gcvspline', s=0.1)  # gcvspline 설치시 활성화
ycalc_uni, base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
ycalc_als, base_als = rampy.baseline(x, y, roi, 'als', lam=10**5, p=0.05)
ycalc_arpls, base_arpsl = rampy.baseline(x, y, roi, 'arPLS', lam=10**6, ratio=0.001)
ycalc_drpls, base_drpsl = rampy.baseline(x, y, roi, 'drPLS')
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 그래프 그리기
plt.figure(dpi=150)
plt.plot(x, y, "k-", label="Raw")
plt.plot(x, base_poly, "-", color="grey", label="다항식 기준선")
plt.plot(x, base_uni, "b-", label="유니스플라인 기준선")
plt.plot(x, base_gcvspl, "-", color="orange", label="GCV스플라인 기준선")  # gcvspline 설치시 활성화
plt.plot(x, base_als, ":", color="purple", label="ALS 기준선")
plt.plot(x, base_arpsl, "-.", color="cyan", label="arPLS 기준선")
plt.plot(x, base_drpsl, "--", color="orange", label="drPLS 기준선")
plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.legend()
plt.show()

# 기준선으로 보정된 데이터 출력
plt.figure(dpi=150)
plt.plot(x, y - base_poly, "-", color="grey", label="다항식 기준선 보정")
plt.plot(x, y - base_uni, "b-", label="유니스플라인 기준선 보정")
plt.plot(x, y - base_gcvspl, "-", color="orange", label="GCV스플라인 기준선 보정")  # gcvspline 설치시 활성화
plt.plot(x, y - base_als, ":", color="purple", label="ALS 기준선 보정")
plt.plot(x, y - base_arpsl, "-.", color="cyan", label="arPLS 기준선 보정")
plt.plot(x, y - base_drpsl, "--", color="orange", label="drPLS 기준선 보정")
plt.plot(x, y - base_rubberband, "--", color="green", label="러버밴드 기준선 보정")

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity (Baseline Corrected)")

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-f095fe434b12> in <cell line: 25>()
#      23
#      24 # 기준선 추정
# ---> 25 ycalc_poly, base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
#      26 ycalc_gcvspl, base_gcvspl = rampy.baseline(x, y, roi, 'gcvspline', s=0.1)  # gcvspline 설치시 활성화
#      27 ycalc_uni, base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
#
# /usr/local/lib/python3.10/dist-packages/rampy/baseline.py in baseline(x_input, y_input, bir, method, **kwargs)
#     103     """
#     104     # we get the signals in the bir
# --> 105     yafit_unscaled = get_portion_interest(x_input,y_input,bir)
#     106
#     107     # signal standard standardization with sklearn
#
# /usr/local/lib/python3.10/dist-packages/rampy/baseline.py in get_portion_interest(x, y, bir)
#      32     birlen = np.array(bir.shape[0])
#      33
# ---> 34     sp = np.transpose(np.vstack((x.reshape(-1),y.reshape(-1))))
#      35     ### selection of bir data
#      36     for i in range(birlen):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %%
import numpy as np
import rampy
from matplotlib import pyplot as plt

# 데이터 로드
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = ['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1).values  # pandas Series에서 numpy 배열로 변환

# 기준선 추정을 위한 구간 설정
roi = np.array([[min(x), max(x)]])

# 기준선 추정
ycalc_poly, base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
ycalc_gcvspl, base_gcvspl = rampy.baseline(x, y, roi, 'gcvspline', s=0.1)  # gcvspline 설치시 활성화
ycalc_uni, base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
ycalc_als, base_als = rampy.baseline(x, y, roi, 'als', lam=10**5, p=0.05)
ycalc_arpls, base_arpsl = rampy.baseline(x, y, roi, 'arPLS', lam=10**6, ratio=0.001)
ycalc_drpls, base_drpsl = rampy.baseline(x, y, roi, 'drPLS')
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 그래프 그리기
plt.figure(dpi=150)
plt.plot(x, y, "k-", label="Raw")
plt.plot(x, base_poly, "-", color="grey", label="다항식 기준선")
plt.plot(x, base_uni, "b-", label="유니스플라인 기준선")
plt.plot(x, base_gcvspl, "-", color="orange", label="GCV스플라인 기준선")  # gcvspline 설치시 활성화
plt.plot(x, base_als, ":", color="purple", label="ALS 기준선")
plt.plot(x, base_arpsl, "-.", color="cyan", label="arPLS 기준선")
plt.plot(x, base_drpsl, "--", color="orange", label="drPLS 기준선")
plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.legend()
plt.show()

# 기준선으로 보정된 데이터 출력
plt.figure(dpi=150)
plt.plot(x, y - base_poly, "-", color="grey", label="다항식 기준선 보정")
plt.plot(x, y - base_uni, "b-", label="유니스플라인 기준선 보정")
plt.plot(x, y - base_gcvspl, "-", color="orange", label="GCV스플라인 기준선 보정")  # gcvspline 설치시 활성화
plt.plot(x, y - base_als, ":", color="purple", label="ALS 기준선 보정")
plt.plot(x, y - base_arpsl, "-.", color="cyan", label="arPLS 기준선 보정")
plt.plot(x, y - base_drpsl, "--", color="orange", label="drPLS 기준선 보정")
plt.plot(x, y - base_rubberband, "--", color="green", label="러버밴드 기준선 보정")

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity (Baseline Corrected)")

plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54637 (\N{HANGUL SYLLABLE HANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45768 (\N{HANGUL SYLLABLE NI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47084 (\N{HANGUL SYLLABLE REO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48180 (\N{HANGUL SYLLABLE BAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48372 (\N{HANGUL SYLLABLE BO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2364                 # force the figure dpi to 72), so we need to set it again here.
#    2365                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366                     result = print_method(
#    2367                         filename,
#    2368                         facecolor=facecolor,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2230                 "bbox_inches_restore"}
#    2231             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234         else:  # Let third-parties do as they see fit.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     510
#     511     def print_to_buffer(self):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     455         *pil_kwargs* and *metadata* are forwarded).
#     456         """
# --> 457         FigureCanvasAgg.draw(self)
#     458         mpl.image.imsave(
#     459             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     392     def draw(self):
#     393         # docstring inherited
# --> 394         self.renderer = self.get_renderer()
#     395         self.renderer.clear()
#     396         # Acquire a lock on the shared font cache.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     382             # Early return in the simple, non-deprecated case (much faster than
#     383             # calling bind()).
# --> 384             return func(*inner_args, **inner_kwargs)
#     385         arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     386         if is_varargs and arguments.get(name):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     409         reuse_renderer = (self._lastKey == key)
#     410         if not reuse_renderer:
# --> 411             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     412             self._lastKey = key
#     413         elif cleared:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      82         self.width = width
#      83         self.height = height
# ---> 84         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      85         self._filter_renderers = []
#      86
#
# ValueError: Image size of 860x116299 pixels is too large. It must be less than 2^16 in each direction.

# %%
import numpy as np
import pandas as pd
import rampy
from matplotlib import pyplot as plt

# 데이터 로드
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = ['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1).values  # pandas Series에서 numpy 배열로 변환

# 기준선 추정을 위한 구간 설정
roi = np.array([[min(x), max(x)]])

# 기준선 추정
ycalc_poly, base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
ycalc_gcvspl, base_gcvspl = rampy.baseline(x, y, roi, 'gcvspline', s=0.1)  # gcvspline 설치시 활성화
ycalc_uni, base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
ycalc_als, base_als = rampy.baseline(x, y, roi, 'als', lam=10**5, p=0.05)
ycalc_arpls, base_arpsl = rampy.baseline(x, y, roi, 'arPLS', lam=10**6, ratio=0.001)
ycalc_drpls, base_drpsl = rampy.baseline(x, y, roi, 'drPLS')
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 그래프 그리기
plt.figure(dpi=150)
plt.plot(x, y, "k-", label="Raw")
plt.plot(x, base_poly, "-", color="grey", label="다항식 기준선")
plt.plot(x, base_uni, "b-", label="유니스플라인 기준선")
plt.plot(x, base_gcvspl, "-", color="orange", label="GCV스플라인 기준선")  # gcvspline 설치시 활성화
plt.plot(x, base_als, ":", color="purple", label="ALS 기준선")
plt.plot(x, base_arpsl, "-.", color="cyan", label="arPLS 기준선")
plt.plot(x, base_drpsl, "--", color="orange", label="drPLS 기준선")
plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.legend()
plt.show()

# 피크가 아닌 부분을 찾기 위한 조건 설정
threshold = 0.02  # 피크로 간주되는 최소 높이 기준 설정

# 피크가 아닌 부분의 인덱스 추출
non_peak_indices = np.where(y - base_poly < threshold)[0]

# 피크가 아닌 부분의 x, y 데이터 추출
non_peak_x = x[non_peak_indices]
non_peak_y = y[non_peak_indices]

# 피크가 아닌 부분을 기준으로 polynomial equation 세 번째 차수로 기준선 추정
non_peak_base = np.polyval(np.polyfit(non_peak_x, non_peak_y, 3), x)

# 그래프 그리기
plt.figure(dpi=150)
plt.plot(x, y, "k-", label="Raw")
plt.plot(x, non_peak_base, "-", color="red", label="Polynomial Baseline")

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54637 (\N{HANGUL SYLLABLE HANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45768 (\N{HANGUL SYLLABLE NI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47084 (\N{HANGUL SYLLABLE REO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48180 (\N{HANGUL SYLLABLE BAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np
import pandas as pd
import rampy
from matplotlib import pyplot as plt

# 데이터 로드
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = ['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1).values  # pandas Series에서 numpy 배열로 변환

# 기준선 추정을 위한 구간 설정
roi = np.array([[min(x), max(x)]])

# 기준선 추정
ycalc_poly, base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
ycalc_gcvspl, base_gcvspl = rampy.baseline(x, y, roi, 'gcvspline', s=0.1)  # gcvspline 설치시 활성화
ycalc_uni, base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
ycalc_als, base_als = rampy.baseline(x, y, roi, 'als', lam=10**5, p=0.05)
ycalc_arpls, base_arpsl = rampy.baseline(x, y, roi, 'arPLS', lam=10**6, ratio=0.001)
ycalc_drpls, base_drpsl = rampy.baseline(x, y, roi, 'drPLS')
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 그래프 그리기
plt.figure(dpi=150)
plt.plot(x, y, "k-", label="Raw")
plt.plot(x, base_poly, "-", color="grey", label="다항식 기준선")
plt.plot(x, base_uni, "b-", label="유니스플라인 기준선")
plt.plot(x, base_gcvspl, "-", color="orange", label="GCV스플라인 기준선")  # gcvspline 설치시 활성화
plt.plot(x, base_als, ":", color="purple", label="ALS 기준선")
plt.plot(x, base_arpsl, "-.", color="cyan", label="arPLS 기준선")
plt.plot(x, base_drpsl, "--", color="orange", label="drPLS 기준선")
plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")

# 기준점 표시
baseline_points = [860, 920]
for point in baseline_points:
    idx = np.abs(x - point).argmin()
    plt.plot(x[idx], base_poly[idx], 'ro')

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54637 (\N{HANGUL SYLLABLE HANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45768 (\N{HANGUL SYLLABLE NI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47084 (\N{HANGUL SYLLABLE REO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48180 (\N{HANGUL SYLLABLE BAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np
import pandas as pd
import rampy
from matplotlib import pyplot as plt

# 데이터 로드
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = ['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1).values  # pandas Series에서 numpy 배열로 변환

# 기준선 추정을 위한 구간 설정
roi = np.array([[min(x), max(x)]])

# 기준선 추정
ycalc_poly, base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
ycalc_gcvspl, base_gcvspl = rampy.baseline(x, y, roi, 'gcvspline', s=0.1)  # gcvspline 설치시 활성화
ycalc_uni, base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
ycalc_als, base_als = rampy.baseline(x, y, roi, 'als', lam=10**5, p=0.05)
ycalc_arpls, base_arpls = rampy.baseline(x, y, roi, 'arPLS', lam=10**6, ratio=0.001)
ycalc_drpls, base_drpls = rampy.baseline(x, y, roi, 'drPLS')
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 그래프 그리기
plt.figure(dpi=150)
plt.plot(x, y, "k-", label="Raw")
plt.plot(x, base_poly, "-", color="grey", label="다항식 기준선")
plt.plot(x, base_uni, "b-", label="유니스플라인 기준선")
plt.plot(x, base_gcvspl, "-", color="orange", label="GCV스플라인 기준선")  # gcvspline 설치시 활성화
plt.plot(x, base_als, ":", color="purple", label="ALS 기준선")
plt.plot(x, base_arpls, "-.", color="cyan", label="arPLS 기준선")
plt.plot(x, base_drpls, "--", color="orange", label="drPLS 기준선")
plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")

# 기준점 표시
baseline_point = 920
idx = np.where(x == baseline_point)[0][0]
plt.plot(x[idx], base_arpls[idx], 'ro')

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-06980ee0e3a2> in <cell line: 47>()
#      45 # 기준점 표시
#      46 baseline_point = 920
# ---> 47 idx = np.where(x == baseline_point)[0][0]
#      48 plt.plot(x[idx], base_arpls[idx], 'ro')
#      49
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import numpy as np
import pandas as pd
import rampy
from matplotlib import pyplot as plt

# 데이터 로드
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = ['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1).values  # pandas Series에서 numpy 배열로 변환

# 기준선 추정을 위한 구간 설정
roi = np.array([[min(x), max(x)]])

# 기준선 추정
ycalc_poly, base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
ycalc_uni, base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
ycalc_als, base_als = rampy.baseline(x, y, roi, 'als', lam=10**5, p=0.05)
ycalc_arpls, base_arpls = rampy.baseline(x, y, roi, 'arPLS', lam=10**6, ratio=0.001)
ycalc_drpls, base_drpls = rampy.baseline(x, y, roi, 'drPLS')
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 그래프 그리기
plt.figure(dpi=150)
plt.plot(x, y, "k-", label="Raw")
plt.plot(x, base_poly, "-", color="grey", label="다항식 기준선")
plt.plot(x, base_uni, "b-", label="유니스플라인 기준선")
plt.plot(x, base_als, ":", color="purple", label="ALS 기준선")
plt.plot(x, base_arpls, "-.", color="cyan", label="arPLS 기준선")
plt.plot(x, base_drpls, "--", color="orange", label="drPLS 기준선")
plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")

# 기준점 표시
baseline_point = 920
idx = np.where(x == baseline_point)[0]
if len(idx) > 0:
    idx = idx[0]
    baseline_line = base_uni  # 유니스플라인을 기준선으로 설정
    plt.plot(x, baseline_line, "g--", label="설정된 기준선")  # 설정된 기준선인 유니스플라인을 그립니다
    plt.plot(x[idx], baseline_line[idx], 'ro')
else:
    print("기준점이 데이터 범위에 없습니다.")

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.legend()
plt.show()
# Out:
# 기준점이 데이터 범위에 없습니다.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54637 (\N{HANGUL SYLLABLE HANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45768 (\N{HANGUL SYLLABLE NI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47084 (\N{HANGUL SYLLABLE REO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48180 (\N{HANGUL SYLLABLE BAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# !pip install rampy
# Out:
# Collecting rampy
#   Downloading rampy-0.4.9-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.10/dist-packages (from rampy) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from rampy) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from rampy) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from rampy) (1.5.3)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (from rampy) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rampy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rampy) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->rampy) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->rampy) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->rampy) (1.16.0)
# Installing collected packages: rampy
# Successfully installed rampy-0.4.9

# %%
 in /usr/local/lib/python3.10/dist-packages (from rampy) (2.0.1)
Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rampy) (2.8.2)
Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rampy) (2022.7.1)
Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->rampy) (1.2.0)
Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->rampy) (3.1.0)
Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->rampy) (1.16.0)
Installing collected packages: rampy
Successfully installed rampy-0.4.9
[ ]
Colab 유료 제품 - 여기에서 계약 취소

check
1초
오후

# %%
import numpy as np
import pandas as pd
import rampy
from matplotlib import pyplot as plt

# 데이터 로드
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = ['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1).values  # pandas Series에서 numpy 배열로 변환

# 기준선 추정을 위한 구간 설정
roi = np.array([[min(x), max(x)]])

# 기준선 추정
ycalc_poly, base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
ycalc_uni, base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
ycalc_als, base_als = rampy.baseline(x, y, roi, 'als', lam=10**5, p=0.05)
ycalc_arpls, base_arpls = rampy.baseline(x, y, roi, 'arPLS', lam=10**6, ratio=0.001)
ycalc_drpls, base_drpls = rampy.baseline(x, y, roi, 'drPLS')
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 그래프 그리기
fig, ax = plt.subplots(dpi=150)
plt.plot(x, y, "k-", label="Raw")
plt.plot(x, base_poly, "-", color="grey", label="다항식 기준선")
plt.plot(x, base_uni, "b-", label="유니스플라인 기준선")
plt.plot(x, base_als, ":", color="purple", label="ALS 기준선")
plt.plot(x, base_arpls, "-.", color="cyan", label="arPLS 기준선")
plt.plot(x, base_drpls, "--", color="orange", label="drPLS 기준선")
plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")

# 그래프 클릭 시 기준선 그리기
points = []

def onclick(event):
    if event.button == 1:  # 좌클릭
        points.append((event.xdata, event.ydata))
        if len(points) == 2:
            x1, y1 = points[0]
            x2, y2 = points[1]
            slope = (y2 - y1) / (x2 - x1)
            baseline_line = y - slope * (x - x1)
            ax.plot(x, baseline_line, "r--", label="선택한 기준선")
            ax.figure.canvas.draw()

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54637 (\N{HANGUL SYLLABLE HANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45768 (\N{HANGUL SYLLABLE NI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47084 (\N{HANGUL SYLLABLE REO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48180 (\N{HANGUL SYLLABLE BAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np
import pandas as pd
import rampy
from matplotlib import pyplot as plt

# 데이터 로드
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = ['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1).values  # pandas Series에서 numpy 배열로 변환

# 기준선 추정을 위한 구간 설정
roi = np.array([[min(x), max(x)]])

# 기준선 추정
ycalc_poly, base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
ycalc_uni, base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
ycalc_als, base_als = rampy.baseline(x, y, roi, 'als', lam=10**5, p=0.05)
ycalc_arpls, base_arpls = rampy.baseline(x, y, roi, 'arPLS', lam=10**6, ratio=0.001)
ycalc_drpls, base_drpls = rampy.baseline(x, y, roi, 'drPLS')
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 그래프 그리기
fig, ax = plt.subplots(dpi=150)
plt.plot(x, y, "k-", label="Raw")
plt.plot(x, base_poly, "-", color="grey", label="다항식 기준선")
plt.plot(x, base_uni, "b-", label="유니스플라인 기준선")
plt.plot(x, base_als, ":", color="purple", label="ALS 기준선")
plt.plot(x, base_arpls, "-.", color="cyan", label="arPLS 기준선")
plt.plot(x, base_drpls, "--", color="orange", label="drPLS 기준선")
plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")

# 그래프 클릭 시 기준선 그리기
points = []

def onclick(event):
    if event.button == 1:  # 좌클릭
        points.append((event.xdata, event.ydata))
        if len(points) == 2:
            x1, y1 = points[0]
            x2, y2 = points[1]
            slope = (y2 - y1) / (x2 - x1)
            baseline_line = y - slope * (x - x1)
            ax.plot(x, baseline_line, "r--", label="선택한 기준선")
            ax.figure.canvas.draw()

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.legend()
fig.canvas.mpl_connect('button_press_event', onclick)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54637 (\N{HANGUL SYLLABLE HANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45768 (\N{HANGUL SYLLABLE NI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47084 (\N{HANGUL SYLLABLE REO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48180 (\N{HANGUL SYLLABLE BAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
pip install rampy
# Out:
# Collecting rampy
#   Downloading rampy-0.4.9-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.10/dist-packages (from rampy) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from rampy) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from rampy) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from rampy) (1.5.3)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (from rampy) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rampy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rampy) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->rampy) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->rampy) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->rampy) (1.16.0)
# Installing collected packages: rampy
# Successfully installed rampy-0.4.9

# %%
import numpy as np
import pandas as pd
import rampy
from matplotlib import pyplot as plt
import mpldatacursor

# 데이터 로드
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = ['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1).values  # pandas Series에서 numpy 배열로 변환

# 기준선 추정을 위한 구간 설정
roi = np.array([[min(x), max(x)]])

# 기준선 추정
ycalc_poly, base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
ycalc_uni, base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
ycalc_als, base_als = rampy.baseline(x, y, roi, 'als', lam=10**5, p=0.05)
ycalc_arpls, base_arpls = rampy.baseline(x, y, roi, 'arPLS', lam=10**6, ratio=0.001)
ycalc_drpls, base_drpls = rampy.baseline(x, y, roi, 'drPLS')
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 그래프 그리기
fig, ax = plt.subplots(dpi=150)
plt.plot(x, y, "k-", label="Raw")
plt.plot(x, base_poly, "-", color="grey", label="다항식 기준선")
plt.plot(x, base_uni, "b-", label="유니스플라인 기준선")
plt.plot(x, base_als, ":", color="purple", label="ALS 기준선")
plt.plot(x, base_arpls, "-.", color="cyan", label="arPLS 기준선")
plt.plot(x, base_drpls, "--", color="orange", label="drPLS 기준선")
plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")

# 그래프 클릭 시 기준선 그리기
points = []

def on_select(sel):
    if len(points) < 2:
        points.append((sel.target[0], sel.target[1]))
        if len(points) == 2:
            x1, y1 = points[0]
            x2, y2 = points[1]
            slope = (y2 - y1) / (x2 - x1)
            baseline_line = y - slope * (x - x1)
            ax.plot(x, baseline_line, "r--", label="선택한 기준선")
            ax.figure.canvas.draw()

mpldatacursor.datacursor(hover=True, bbox=dict(alpha=1, fc='w'), draggable=True).connect("select", on_select)

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-bb6cfecd8936> in <cell line: 58>()
#      56             ax.figure.canvas.draw()
#      57
# ---> 58 mpldatacursor.datacursor(hover=True, bbox=dict(alpha=1, fc='w'), draggable=True).connect("select", on_select)
#      59
#      60 plt.xlabel("Axis [nm]")
#
# /usr/local/lib/python3.10/dist-packages/mpldatacursor/convenience.py in datacursor(artists, axes, **kwargs)
#     167         artists = [artist for ax in axes for artist in plotted_artists(ax)]
#     168
# --> 169     return DataCursor(artists, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/mpldatacursor/datacursor.py in __init__(self, artists, tolerance, formatter, point_labels, display, draggable, hover, props_override, keybindings, date_format, display_button, hide_button, keep_inside, **kwargs)
#     202         if self.display is not 'multiple':
#     203             for ax in self.axes:
# --> 204                 self.annotations[ax] = self.annotate(ax, **kwargs)
#     205                 # Hide the annotation box until clicked...
#     206                 self.annotations[ax].set_visible(False)
#
# /usr/local/lib/python3.10/dist-packages/mpldatacursor/datacursor.py in annotate(self, ax, **kwargs)
#     442         # Place the annotation in the figure instead of the axes so that it
#     443         # doesn't get hidden behind other subplots (zorder won't fix that).
# --> 444         ax.figure.texts.append(ax.texts.pop())
#     445
#     446         # Create a draggable annotation box, if required.
#
# AttributeError: 'ArtistList' object has no attribute 'pop'

# %%
# !pip install mpldatacursor
# Out:
# Collecting mpldatacursor
#   Downloading mpldatacursor-0.7.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: matplotlib>=0.9 in /usr/local/lib/python3.10/dist-packages (from mpldatacursor) (3.7.1)
# Requirement already satisfied: numpy>=1.1 in /usr/local/lib/python3.10/dist-packages (from mpldatacursor) (1.22.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=0.9->mpldatacursor) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=0.9->mpldatacursor) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=0.9->mpldatacursor) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=0.9->mpldatacursor) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=0.9->mpldatacursor) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=0.9->mpldatacursor) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=0.9->mpldatacursor) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=0.9->mpldatacursor) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=0.9->mpldatacursor) (1.16.0)
# Installing collected packages: mpldatacursor
# Successfully installed mpldatacursor-0.7.1

# %%
import numpy as np
import pandas as pd
import rampy
from matplotlib import pyplot as plt

# 데이터 로드
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = ['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1).values  # pandas Series에서 numpy 배열로 변환

# 기준선 추정을 위한 구간 설정
roi = np.array([[min(x), max(x)]])

# 기준선 추정
ycalc_poly, base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
ycalc_uni, base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
ycalc_als, base_als = rampy.baseline(x, y, roi, 'als', lam=10**5, p=0.05)
ycalc_arpls, base_arpls = rampy.baseline(x, y, roi, 'arPLS', lam=10**6, ratio=0.001)
ycalc_drpls, base_drpls = rampy.baseline(x, y, roi, 'drPLS')
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 그래프 그리기
fig, ax = plt.subplots(dpi=150)
plt.plot(x, y, "k-", label="Raw")
plt.plot(x, base_poly, "-", color="grey", label="다항식 기준선")
plt.plot(x, base_uni, "b-", label="유니스플라인 기준선")
plt.plot(x, base_als, ":", color="purple", label="ALS 기준선")
plt.plot(x, base_arpls, "-.", color="cyan", label="arPLS 기준선")
plt.plot(x, base_drpls, "--", color="orange", label="drPLS 기준선")
plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")

# 기준선 선택을 위한 변수 초기화
points = []
line = None

def on_pick(event):
    global line
    if len(points) < 2:
        points.append((event.mouseevent.xdata, event.mouseevent.ydata))
        if len(points) == 2:
            x1, y1 = points[0]
            x2, y2 = points[1]
            slope = (y2 - y1) / (x2 - x1)
            baseline_line = y - slope * (x - x1)
            line, = ax.plot(x, baseline_line, "r--", label="선택한 기준선")
            plt.legend()
            plt.draw()

# 이벤트 처리기 등록
fig.canvas.mpl_connect('pick_event', on_pick)

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.show()

# %%
import numpy as np
import pandas as pd
import rampy
from matplotlib import pyplot as plt
from IPython.display import display
import ipywidgets as widgets

# 데이터 로드
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = ['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1).values  # pandas Series에서 numpy 배열로 변환

# 기준선 추정을 위한 구간 설정
roi = np.array([[min(x), max(x)]])

# 기준선 추정
ycalc_poly, base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
ycalc_uni, base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
ycalc_als, base_als = rampy.baseline(x, y, roi, 'als', lam=10**5, p=0.05)
ycalc_arpls, base_arpls = rampy.baseline(x, y, roi, 'arPLS', lam=10**6, ratio=0.001)
ycalc_drpls, base_drpls = rampy.baseline(x, y, roi, 'drPLS')
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 그래프 그리기
fig, ax = plt.subplots(dpi=150)
line_raw, = plt.plot(x, y, "k-", label="Raw")
line_poly, = plt.plot(x, base_poly, "-", color="grey", label="다항식 기준선")
line_uni, = plt.plot(x, base_uni, "b-", label="유니스플라인 기준선")
line_als, = plt.plot(x, base_als, ":", color="purple", label="ALS 기준선")
line_arpls, = plt.plot(x, base_arpls, "-.", color="cyan", label="arPLS 기준선")
line_drpls, = plt.plot(x, base_drpls, "--", color="orange", label="drPLS 기준선")
line_rubberband, = plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")

# 그래프 클릭 시 기준선 그리기
points = []

def on_click(event):
    if event.inaxes == ax:
        if len(points) < 2:
            points.append((event.xdata, event.ydata))
            if len(points) == 2:
                x1, y1 = points[0]
                x2, y2 = points[1]
                slope = (y2 - y1) / (x2 - x1)
                baseline_line = y - slope * (x - x1)
                line_baseline, = ax.plot(x, baseline_line, "r--", label="선택한 기준선")
                display(line_baseline)
                points.clear()

fig.canvas.mpl_connect('button_press_event', on_click)

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54637 (\N{HANGUL SYLLABLE HANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45768 (\N{HANGUL SYLLABLE NI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47084 (\N{HANGUL SYLLABLE REO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48180 (\N{HANGUL SYLLABLE BAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# !pip install peakutils
# Out:
# Collecting peakutils
#   Downloading PeakUtils-1.3.4-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from peakutils) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from peakutils) (1.10.1)
# Installing collected packages: peakutils
# Successfully installed peakutils-1.3.4

# %%
# !pip install mplcursors
# Out:
# Collecting mplcursors
#   Downloading mplcursors-0.5.2.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.0/89.0 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib>=3.1 in /usr/local/lib/python3.10/dist-packages (from mplcursors) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->mplcursors) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->mplcursors) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->mplcursors) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->mplcursors) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->mplcursors) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->mplcursors) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->mplcursors) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->mplcursors) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->mplcursors) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1->mplcursors) (1.16.0)
# Building wheels for collected packages: mplcursors
#   Building wheel for mplcursors (setup.py) ... done
#   Created wheel for mplcursors: filename=mplcursors-0.5.2-py3-none-any.whl size=21054 sha256=be29e040b2d36ef12c7e109baac5b83bdece65d566b51a6b5797b1df195870f8
#   Stored in directory: /root/.cache/pip/wheels/b5/5b/fb/aed35cc15262c380536820fa3cb2e2d41fb52450de918a6785
# Successfully built mplcursors
# Installing collected packages: mplcursors
# Successfully installed mplcursors-0.5.2

# %%
import numpy as np
import pandas as pd
import rampy
from matplotlib import pyplot as plt
import mplcursors

# 데이터 로드
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = ['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1).values  # pandas Series에서 numpy 배열로 변환

# 기준선 추정을 위한 구간 설정
roi = np.array([[min(x), max(x)]])

# 기준선 추정
ycalc_poly, base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
ycalc_uni, base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
ycalc_als, base_als = rampy.baseline(x, y, roi, 'als', lam=10**5, p=0.05)
ycalc_arpls, base_arpls = rampy.baseline(x, y, roi, 'arPLS', lam=10**6, ratio=0.001)
ycalc_drpls, base_drpls = rampy.baseline(x, y, roi, 'drPLS')
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 그래프 그리기
fig, ax = plt.subplots(dpi=150)
line_raw, = plt.plot(x, y, "k-", label="Raw")
line_poly, = plt.plot(x, base_poly, "-", color="grey", label="다항식 기준선")
line_uni, = plt.plot(x, base_uni, "b-", label="유니스플라인 기준선")
line_als, = plt.plot(x, base_als, ":", color="purple", label="ALS 기준선")
line_arpls, = plt.plot(x, base_arpls, "-.", color="cyan", label="arPLS 기준선")
line_drpls, = plt.plot(x, base_drpls, "--", color="orange", label="drPLS 기준선")
line_rubberband, = plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")

# 그래프 클릭 시 기준선 그리기
points = []

def on_click(event):
    if event.inaxes == ax:
        if len(points) < 2:
            points.append((event.xdata, event.ydata))
            if len(points) == 2:
                x1, y1 = points[0]
                x2, y2 = points[1]
                slope = (y2 - y1) / (x2 - x1)
                baseline_line = y - slope * (x - x1)
                line_baseline, = ax.plot(x, baseline_line, "r--", label="선택한 기준선")
                mplcursors.cursor([line_baseline])
                points.clear()

fig.canvas.mpl_connect('button_press_event', on_click)

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54637 (\N{HANGUL SYLLABLE HANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45768 (\N{HANGUL SYLLABLE NI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47084 (\N{HANGUL SYLLABLE REO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48180 (\N{HANGUL SYLLABLE BAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np
import pandas as pd
import rampy
from matplotlib import pyplot as plt

# 데이터 로드
df = pd.read_csv('UR2 BXPC3 raman raw data__24h.csv')

# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = ['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1).values  # pandas Series에서 numpy 배열로 변환

# 기준선 추정을 위한 구간 설정
roi = np.array([[min(x), max(x)]])

# 기준선 추정
ycalc_poly, base_poly = rampy.baseline(x, y, roi, 'poly', polynomial_order=4)
ycalc_uni, base_uni = rampy.baseline(x, y, roi, 'unispline', s=1e0)
ycalc_als, base_als = rampy.baseline(x, y, roi, 'als', lam=10**5, p=0.05)
ycalc_arpls, base_arpls = rampy.baseline(x, y, roi, 'arPLS', lam=10**6, ratio=0.001)
ycalc_drpls, base_drpls = rampy.baseline(x, y, roi, 'drPLS')
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 그래프 그리기
fig, ax = plt.subplots(dpi=150)
line_raw, = plt.plot(x, y, "k-", label="Raw")
line_poly, = plt.plot(x, base_poly, "-", color="grey", label="다항식 기준선")
line_uni, = plt.plot(x, base_uni, "b-", label="유니스플라인 기준선")
line_als, = plt.plot(x, base_als, ":", color="purple", label="ALS 기준선")
line_arpls, = plt.plot(x, base_arpls, "-.", color="cyan", label="arPLS 기준선")
line_drpls, = plt.plot(x, base_drpls, "--", color="orange", label="drPLS 기준선")
line_rubberband, = plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")

# 그래프 클릭 시 기준선 그리기
points = []

def on_click(event):
    if event.button == 1:  # 좌클릭
        points.append((event.xdata, event.ydata))
        if len(points) == 2:
            x1, y1 = points[0]
            x2, y2 = points[1]
            slope = (y2 - y1) / (x2 - x1)
            baseline_line = y - slope * (x - x1)
            line_baseline, = ax.plot(x, baseline_line, "r--", label="선택한 기준선")
            plt.legend()  # 범례 업데이트
            plt.draw()  # 그래프 업데이트
            points.clear()

cid = fig.canvas.mpl_connect('button_press_event', on_click)

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54637 (\N{HANGUL SYLLABLE HANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45768 (\N{HANGUL SYLLABLE NI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47084 (\N{HANGUL SYLLABLE REO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48180 (\N{HANGUL SYLLABLE BAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# !pip install peakutils
# Out:
# Collecting peakutils
#   Downloading PeakUtils-1.3.4-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from peakutils) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from peakutils) (1.10.1)
# Installing collected packages: peakutils
# Successfully installed peakutils-1.3.4

# %%
import numpy as np
import pandas as pd
import rampy
from matplotlib import pyplot as plt
from BaselineRemoval import BaselineRemoval

# 데이터 로드
df = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = ['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1).values  # pandas Series에서 numpy 배열로 변환

# 다항식 차수
polynomial_degree = 3

# 베이스라인 조정
baseObj = BaselineRemoval(y)
Modpoly_output = baseObj.ModPoly(polynomial_degree)
Imodpoly_output = baseObj.IModPoly(polynomial_degree)
Zhangfit_output = baseObj.ZhangFit()

#print('Raw Data:',y)
#print('Modpoly base corrected values:',Modpoly_output)
#print('IModPoly base corrected values:',Imodpoly_output)
#print('ZhangFit base corrected values:',Zhangfit_output)

# 그래프 그리기
plt.figure(figsize=(15,10))
plt.plot(x, y, label='raw', color='blue')
plt.plot(x, Modpoly_output, label='modpoly', color='green')
plt.plot(x, Imodpoly_output, label='Imodpoly', color='pink')
plt.plot(x, Zhangfit_output, label='Zhangfit', color='red')
plt.axhline(y=0, color='gray')

plt.legend()
plt.show()

# %%
# !pip install rampy
# Out:
# Collecting rampy
#   Downloading rampy-0.4.9-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.10/dist-packages (from rampy) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from rampy) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from rampy) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from rampy) (1.5.3)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (from rampy) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rampy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rampy) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->rampy) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->rampy) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->rampy) (1.16.0)
# Installing collected packages: rampy
# Successfully installed rampy-0.4.9

# %%
# !pip install BaselineRemoval
# Out:
# Collecting BaselineRemoval
#   Downloading BaselineRemoval-0.1.4-py3-none-any.whl (6.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from BaselineRemoval) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from BaselineRemoval) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from BaselineRemoval) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->BaselineRemoval) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->BaselineRemoval) (3.1.0)
# Installing collected packages: BaselineRemoval
# Successfully installed BaselineRemoval-0.1.4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 주어진 데이터를 DataFrame으로 읽어옵니다.
data = pd.read_csv('/content/UR2 BXPC3 raman raw data__24h.csv')

# x축 데이터
x = data['Axis [nm]']

# y축 데이터 (ROI 1부터 ROI 13까지)
y = data.iloc[:, 1:]

# baseline 계산 (ROI 1부터 ROI 13까지 평균값)
baseline = np.mean(y.values, axis=1)

# 그래프 그리기
plt.figure(figsize=(10, 6))

# ROI 1부터 ROI 13까지 그래프 그리기
for i in range(y.shape[1]):
    plt.plot(x, y.iloc[:, i], label='ROI {}'.format(i+1))

# baseline 그래프 그리기
plt.plot(x, baseline, 'k--', label='Baseline')

# 그래프 제목과 축 레이블 설정
plt.title('ROI Analysis')
plt.xlabel('Axis [nm]')
plt.ylabel('Intensity')

# 범례 표시
plt.legend()

# 그래프 출력
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import sparse
from scipy.sparse.linalg import spsolve
from scipy.signal import find_peaks, peak_prominences

# 파일 불러오기
file = '/content/UR2 BXPC3 raman raw data__24h.csv'
df = pd.read_csv(file)
# x축 값 지정
x = df['Axis [nm]'].replace('[\$,]', '', regex=True).astype(float)

# y축 값 지정
y = df['ROI 1 []'].replace('[\$,]', '', regex=True).astype(float)

# 기준점 개수 n 입력받기
n = int(input("기준점 개수: "))

# 기준점 예외처리
if n < 2:
    print("기준점은 2개 이상 필요합니다.")
    exit()

# 기준점 인덱스
nlist = []
for i in range(0, n - 1):
    nlist.append(int(len(x) / (n - 1) * i))
nlist.append(len(x) - 1)

# 기준점 x, y좌표
c = []
d = []
for i in nlist:
    c.append(x[i])
    d.append(y[i])

# Baseline estimation 함수
def baseline_als(y, lam, p, niter=100):
    L = len(y)
    D = sparse.diags([1, -2, 1], [0, -1, -2], shape=(L, L - 2))
    w = np.ones(L)
    for i in range(niter):
        W = sparse.spdiags(w, 0, L, L)
        Z = W + lam * D.dot(D.transpose())
        z = spsolve(Z, w * y)
        w = p * (y > z) + (1 - p) * (y < z)
    return z

# Baseline subtraction을 적용한 데이터
baseline_subtracted = y - baseline_als(y, lam=10**5, p=0.01)

# peak값 찾기
peaks, _ = find_peaks(baseline_subtracted, height=0, width=2)
prominences = peak_prominences(baseline_subtracted, peaks)[0]
prominence_new = np.percentile(prominences, [0, 25, 50, 75, 100], interpolation='nearest')[2]
peaks, _ = find_peaks(baseline_subtracted, prominence=prominence_new)

# 추가 데이터
additional_data = pd.read_excel('/content/additional_data.xlsx')

# 필요한 성분과 해당하는 주파수 가져오기
assignment = additional_data['Assignment']
frequency = additional_data['Frequency(RAMAN)']
sample = additional_data['Samle']

# 그래프 형식 지정
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(18, 12))

# ax1 그래프 (기존, 기준점)
ax1.plot(x, y, color='black', label='Mix spectrum with noise')
ax1.plot(c, d, 'ro-')
ax1.set_title('Baseline estimation', fontsize=15)
ax1.set_xlabel('Wavelength', fontsize=15)
ax1.set_ylabel('Intensity', fontsize=15)
ax1.legend()

# ax2 그래프 (기준점 삭제된 그래프)
ax2.plot(x, baseline_subtracted, color='black', label='Baseline subtracted spectrum')
ax2.axhline(y=0, color='green', label='y=0')
ax2.set_title('Baseline Subtraction', fontsize=15)
ax2.set_xlabel('Wavelength', fontsize=15)
ax2.set_ylabel('Intensity', fontsize=15)
ax2.legend()

# 피크점 수치 출력
for i in range(len(peaks)):
    x_value = x[peaks[i]]  # 피크의 x 값
    y_value = baseline_subtracted[peaks[i]]  # 피크의 y 값
    ax2.text(x_value, y_value, f'({x_value:.2f}, {y_value:.2f})', fontsize=8, verticalalignment='bottom')

# 그래프 띄우기
plt.show()
# Out:
# 기준점 개수: 300
# <ipython-input-4-ff0d87c1ff89>:56: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   prominence_new = np.percentile(prominences, [0, 25, 50, 75, 100], interpolation='nearest')[2]

# %%
import numpy as np
import pandas as pd
import rampy
from matplotlib import pyplot as plt

# 데이터 로드
df = pd.read_csv('UR2 BXPC3 raman raw data__24h.csv')

# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = ['ROI 1 []', 'ROI 2 []', 'ROI 3 []', 'ROI 4 []', 'ROI 5 []', 'ROI 6 []', 'ROI 7 []', 'ROI 8 []', 'ROI 9 []', 'ROI 10 []', 'ROI 11 []', 'ROI 12 []', 'ROI 13 []']
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1).values  # pandas Series에서 numpy 배열로 변환

# 기준선 추정을 위한 구간 설정
roi = np.array([[min(x), max(x)]])

# 기준선 추정
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 그래프 그리기
fig, ax = plt.subplots(dpi=150)
line_raw, = plt.plot(x, y, "k-", label="Raw")
line_rubberband, = plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")

# 그래프 클릭 시 기준선 그리기
points = []

def on_click(event):
    if event.button == 1:  # 좌클릭
        points.append((event.xdata, event.ydata))
        if len(points) == 2:
            x1, y1 = points[0]
            x2, y2 = points[1]
            slope = (y2 - y1) / (x2 - x1)
            baseline_line = y - slope * (x - x1)
            line_baseline, = ax.plot(x, baseline_line, "r--", label="선택한 기준선")
            # Baseline subtraction
            y_subtracted = y - baseline_line
            line_subtracted, = plt.plot(x, y_subtracted, label="Baseline Subtracted")
            plt.legend()  # 범례 업데이트
            plt.draw()  # 그래프 업데이트
            points.clear()

cid = fig.canvas.mpl_connect('button_press_event', on_click)

# line_rubberband을 baseline으로 설정
y = base_rubberband

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47084 (\N{HANGUL SYLLABLE REO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48180 (\N{HANGUL SYLLABLE BAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# !pip install rampy
# Out:
# Collecting rampy
#   Downloading rampy-0.4.9-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.10/dist-packages (from rampy) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from rampy) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from rampy) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from rampy) (1.5.3)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (from rampy) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rampy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rampy) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->rampy) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->rampy) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->rampy) (1.16.0)
# Installing collected packages: rampy
# Successfully installed rampy-0.4.9

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import sparse
from scipy.sparse.linalg import spsolve
from scipy.signal import find_peaks, peak_prominences

# 파일 불러오기
file = '/content/UR2 BXPC3 raman raw data__24h.csv'
df = pd.read_csv(file)
# x축 값 지정
x = df['Axis [nm]'].replace('[\$,]', '', regex=True).astype(float)

# y축 값 지정
y = df['ROI 1 []'].replace('[\$,]', '', regex=True).astype(float)

# 기준점 개수 n 입력받기
n = int(input("기준점 개수: "))

# 기준점 예외처리
if n < 2:
    print("기준점은 2개 이상 필요합니다.")
    exit()

# 기준점 인덱스
nlist = []
for i in range(0, n - 1):
    nlist.append(int(len(x) / (n - 1) * i))
nlist.append(len(x) - 1)

# 기준점 x, y좌표
c = []
d = []
for i in nlist:
    c.append(x[i])
    d.append(y[i])

# Baseline estimation 함수
def baseline_als(y, lam, p, niter=100):
    L = len(y)
    D = sparse.diags([1, -2, 1], [0, -1, -2], shape=(L, L - 2))
    w = np.ones(L)
    for i in range(niter):
        W = sparse.spdiags(w, 0, L, L)
        Z = W + lam * D.dot(D.transpose())
        z = spsolve(Z, w * y)
        w = p * (y > z) + (1 - p) * (y < z)
    return z

# Baseline subtraction을 적용한 데이터
baseline_subtracted = y - baseline_als(y, lam=10**5, p=0.01)

# peak값 찾기
peaks, _ = find_peaks(baseline_subtracted, height=0, width=2)
prominences = peak_prominences(baseline_subtracted, peaks)[0]
prominence_new = np.percentile(prominences, [0, 25, 50, 75, 100], interpolation='nearest')[2]
peaks, _ = find_peaks(baseline_subtracted, prominence=prominence_new)


# 필요한 성분과 해당하는 주파수 가져오기
assignment = additional_data['Assignment']
frequency = additional_data['Frequency(RAMAN)']
sample = additional_data['Samle']

# 그래프 형식 지정
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(18, 12))

# ax1 그래프 (기존, 기준점)
ax1.plot(x, y, color='black', label='Mix spectrum with noise')
ax1.plot(c, d, 'ro-')
ax1.set_title('Baseline estimation', fontsize=15)
ax1.set_xlabel('Wavelength', fontsize=15)
ax1.set_ylabel('Intensity', fontsize=15)
ax1.legend()

# ax2 그래프 (기준점 삭제된 그래프)
ax2.plot(x, baseline_subtracted, color='black', label='Baseline subtracted spectrum')
ax2.axhline(y=0, color='green', label='y=0')
ax2.set_title('Baseline Subtraction', fontsize=15)
ax2.set_xlabel('Wavelength', fontsize=15)
ax2.set_ylabel('Intensity', fontsize=15)
ax2.legend()

# 피크점 수치 출력
for i in range(len(peaks)):
    x_value = x[peaks[i]]  # 피크의 x 값
    y_value = baseline_subtracted[peaks[i]]  # 피크의 y 값
    ax2.text(x_value, y_value, f'({x_value:.2f}, {y_value:.2f})', fontsize=8, verticalalignment='bottom')

# 그래프 띄우기
plt.show()

# %%
import numpy as np
import pandas as pd
import rampy
from matplotlib import pyplot as plt

# 데이터 로드
df = pd.read_csv('UR2 BXPC3 raman raw data__24h.csv')

# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = df.columns[df.columns.str.startswith('ROI')]
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1).values  # pandas Series에서 numpy 배열로 변환

# 기준선 추정을 위한 구간 설정
roi = np.array([[min(x), max(x)]])

# 기준선 추정
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 그래프 그리기
fig, ax = plt.subplots(dpi=150)
line_raw, = plt.plot(x, y, "k-", label="Raw")
line_rubberband, = plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")



# line_rubberband을 baseline으로 설정
y = base_rubberband

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47084 (\N{HANGUL SYLLABLE REO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48180 (\N{HANGUL SYLLABLE BAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# !pip install rampy
# Out:
# Collecting rampy
#   Downloading rampy-0.4.9-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.10/dist-packages (from rampy) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from rampy) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from rampy) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from rampy) (1.5.3)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (from rampy) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rampy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->rampy) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->rampy) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->rampy) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->rampy) (1.16.0)
# Installing collected packages: rampy
# Successfully installed rampy-0.4.9

# %%
import numpy as np
import pandas as pd
import rampy
from matplotlib import pyplot as plt

# 데이터 로드
df = pd.read_csv('UR2 BXPC3 raman raw data__24h.csv')

# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = df.columns[df.columns.str.startswith('ROI')]
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1).values  # pandas Series에서 numpy 배열로 변환

# 기준선 추정을 위한 구간 설정
roi = np.array([[min(x), max(x)]])

# 기준선 추정
ycalc_rubberband, base_rubberband = rampy.baseline(x, y, roi, 'rubberband')

# 기준선을 0까지 내리기
baseline_min = np.min(base_rubberband)
baseline_max = np.max(base_rubberband)
baseline_line = np.linspace(baseline_min, baseline_max, len(x))
y -= baseline_line

# 그래프 그리기
fig, ax = plt.subplots(dpi=150)
line_raw, = plt.plot(x, y, "k-", label="Baseline Corrected")

plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.legend()
plt.show()

# %%
# !pip install spsolve
# Out:
# ERROR: Could not find a version that satisfies the requirement spsolve (from versions: none)
# ERROR: No matching distribution found for spsolve

# %%
import numpy as np
import pandas as pd
import rampy
from matplotlib import pyplot as plt

# 데이터 로드
df = pd.read_csv('UR2 BXPC3 raman raw data__24h.csv')


# 소수점 둘째 자리까지 반올림
df = df.round(2)

# 관심 영역 선택 (ROI)
roi_columns = df.columns[df.columns.str.startswith('ROI')]
roi_data = df[roi_columns]

# X축 데이터
x = df['Axis [nm]'].values

# Y축 데이터
y = roi_data.mean(axis=1).values  # pandas Series에서 numpy 배열로 변환


# 그래프 그리기
fig, ax = plt.subplots(dpi=150)
line_raw, = plt.plot(x, y, "k-", label="Raw")
#line_rubberband, = plt.plot(x, base_rubberband, "--", color="green", label="러버밴드 기준선")



plt.xlabel("Axis [nm]")
plt.ylabel("Intensity")

plt.legend()
plt.show()
